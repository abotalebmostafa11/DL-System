# %% [markdown]
# <a href="https://colab.research.google.com/github/abotalebmostafa11/DL-System/blob/main/LSTM_deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17e01c7e-f676-4b2f-80ee-267b7ada3893" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17e01c7e-f676-4b2f-80ee-267b7ada3893">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Deaths.csv to Deaths.csv

# %%
# LSTM for Forecasting Covid 19 problem In Russian Fderation
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.layers import Dense,RepeatVector,LSTM,Dropout,GRU,Dense,SimpleRNN,Embedding 
from keras.callbacks import ModelCheckpoint, TensorBoard, Callback, EarlyStopping
from tensorflow.keras.layers import Flatten, Conv1D, MaxPooling1D
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Bidirectional, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, TimeDistributed
from keras.utils.vis_utils import plot_model
from keras.models import Model, load_model
from keras.layers import Dense, Softmax
from sklearn.metrics import r2_score
from keras.models import Sequential
import matplotlib.pyplot as plt
from pandas import read_csv
from numpy import array
import pandas as pd
import numpy as np
import numpy
import math

# %%
Data_Name="Deaths.csv"
Use_Percent = True
if Use_Percent:
    train_Percent = 0.95
else:
    Testing_Rows = 0
Forecasting_days = 10 # how many days that you want to forecast?
create_new_model = True
Time="days"
Implementation="Covid 19 daily deaths Cases in Russia"
plot_title="Modelling and forecasting deaths cases in Russia by using LSTM Model "
Model_Name="lstm"

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv(Data_Name, usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
if Use_Percent:
    train_size = int(len(dataset) * (train_Percent))
    test_size = len(dataset) - train_size
    pass
else:
    train_size = len(dataset) - Testing_Rows
    test_size = Testing_Rows
    pass

#train_size = int(len(dataset) * train_Percent)
#test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back=int(input('LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:'))
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
#trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
#testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = numpy.reshape(testX, (testX.shape[0], look_back, 1))
trainY = trainY.T
testY = testY.T
print(f'trainX = {trainX.shape}')
print(f'trainY = {trainY.shape}')
print(f'testX = {testX.shape}')
print(f'testY = {testY.shape}')
# Out:
# LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:2
# trainX = (795, 2, 1)
# trainY = (795,)
# testX = (39, 2, 1)
# testY = (39,)

# %%
# %%
if create_new_model:
    model = Sequential()
    n_input = 12
    n_features= 1
    generator = TimeseriesGenerator(dataset, dataset, length=n_input, batch_size=n_features)
    early_stop = EarlyStopping(monitor = "loss", mode = "min", patience = 7)
    #for layer in Model_Name:
    if Model_Name.lower() == "bilstm":
        # create and fit the BILSTM for Regression network (bilstm)
        print('Machine learning software = => create and fit the BILSTM for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN,activation=activation, input_shape=(look_back,1))))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked bilstm":
        # create and fit the BILSTM stack network (stacked bilstm)
        print('Machine learning software = => create and fit the stacked bilstm for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back,1))))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1))))
        model.add(Bidirectional(LSTM(20)))
        model.add(Dense(1))
    if  Model_Name.lower() == "convlstms":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstms)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(Conv1D(filters=128, kernel_size=2, activation=activation))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(RepeatVector(30))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Bidirectional(LSTM(128, activation=activation)))
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "conv":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "lstm":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked lstm":
        print('Machine learning software = => create and fit the stacked lstm for Regression network...')
        # create and fit the Stacked LSTM for Regression network (stacked lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(20))
        model.add(Dense(1))     
    if  Model_Name.lower() == "gru":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(GRU(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    model.compile(loss=inputloss_function, optimizer=inputoptimizer_name,metrics=['accuracy'])
    history =model.fit(trainX, trainY, epochs=N_epochs, batch_size=1, verbose=True,validation_split=0.2, shuffle=True)
    print(history.history.keys())
    #  "Accuracy"
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('Accuracy.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    # "Loss" # plot train and validation loss
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model train vs validation loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('plot train and validation loss.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    model.save(Model_Name)
else:
    model = load_model(Model_Name)
    model.summary()
# Out:
# Machine learning software = => create and fit the lstm for Regression network...
# Enter the number of epochs:300
# Enter the Loss Function:MeanSquaredError
# Enter the Optimizer Name:adam
# Enter the activation function name:relu
# Enter the number of neurans:200
# Epoch 1/300
# 636/636 [==============================] - 7s 9ms/step - loss: 0.0065 - accuracy: 0.1289 - val_loss: 0.0076 - val_accuracy: 0.0126
# Epoch 2/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0015 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 3/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0033 - val_accuracy: 0.0126
# Epoch 4/300
# 636/636 [==============================] - 2s 3ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 5/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 9.0739e-04 - val_accuracy: 0.0126
# Epoch 6/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 5.9401e-04 - val_accuracy: 0.0126
# Epoch 7/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0077 - val_accuracy: 0.0126
# Epoch 8/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 8.8603e-04 - val_accuracy: 0.0126
# Epoch 9/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0072 - val_accuracy: 0.0126
# Epoch 10/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 4.0820e-04 - val_accuracy: 0.0126
# Epoch 11/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 5.1491e-04 - val_accuracy: 0.0126
# Epoch 12/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 5.4656e-04 - val_accuracy: 0.0126
# Epoch 13/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 14/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 15/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 6.7277e-04 - val_accuracy: 0.0126
# Epoch 16/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 8.5966e-04 - val_accuracy: 0.0126
# Epoch 17/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 18/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0034 - val_accuracy: 0.0126
# Epoch 19/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.3846e-04 - val_accuracy: 0.0126
# Epoch 20/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 21/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 22/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0043 - val_accuracy: 0.0126
# Epoch 23/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0047 - val_accuracy: 0.0126
# Epoch 24/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.8050e-04 - val_accuracy: 0.0126
# Epoch 25/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.2998e-04 - val_accuracy: 0.0126
# Epoch 26/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 9.1963e-04 - val_accuracy: 0.0126
# Epoch 27/300
# 636/636 [==============================] - 2s 3ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 28/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 29/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 30/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.0588e-04 - val_accuracy: 0.0126
# Epoch 31/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.4950e-04 - val_accuracy: 0.0126
# Epoch 32/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 8.9154e-04 - val_accuracy: 0.0126
# Epoch 33/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 34/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 9.9894e-04 - val_accuracy: 0.0126
# Epoch 35/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7692e-04 - accuracy: 0.1289 - val_loss: 0.0050 - val_accuracy: 0.0126
# Epoch 36/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.1013e-04 - val_accuracy: 0.0126
# Epoch 37/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8443e-04 - accuracy: 0.1289 - val_loss: 8.8451e-04 - val_accuracy: 0.0126
# Epoch 38/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 39/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7834e-04 - accuracy: 0.1289 - val_loss: 5.7715e-04 - val_accuracy: 0.0126
# Epoch 40/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 41/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9473e-04 - accuracy: 0.1289 - val_loss: 7.4239e-04 - val_accuracy: 0.0126
# Epoch 42/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.2039e-04 - val_accuracy: 0.0126
# Epoch 43/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6877e-04 - accuracy: 0.1289 - val_loss: 6.1757e-04 - val_accuracy: 0.0126
# Epoch 44/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 45/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.3252e-04 - val_accuracy: 0.0126
# Epoch 46/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7575e-04 - accuracy: 0.1289 - val_loss: 6.7787e-04 - val_accuracy: 0.0126
# Epoch 47/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9699e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 48/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7467e-04 - accuracy: 0.1289 - val_loss: 5.2548e-04 - val_accuracy: 0.0126
# Epoch 49/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5625e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 50/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 8.2230e-04 - val_accuracy: 0.0126
# Epoch 51/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.4301e-04 - val_accuracy: 0.0126
# Epoch 52/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9825e-04 - accuracy: 0.1289 - val_loss: 0.0026 - val_accuracy: 0.0126
# Epoch 53/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.8153e-04 - val_accuracy: 0.0126
# Epoch 54/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6922e-04 - accuracy: 0.1289 - val_loss: 0.0040 - val_accuracy: 0.0126
# Epoch 55/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7593e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 56/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 6.4340e-04 - val_accuracy: 0.0126
# Epoch 57/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5417e-04 - accuracy: 0.1289 - val_loss: 0.0061 - val_accuracy: 0.0126
# Epoch 58/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.8862e-04 - accuracy: 0.1289 - val_loss: 8.6419e-04 - val_accuracy: 0.0126
# Epoch 59/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8813e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 60/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7273e-04 - accuracy: 0.1289 - val_loss: 5.4500e-04 - val_accuracy: 0.0126
# Epoch 61/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 62/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0029 - val_accuracy: 0.0126
# Epoch 63/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5995e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 64/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4360e-04 - accuracy: 0.1289 - val_loss: 6.5286e-04 - val_accuracy: 0.0126
# Epoch 65/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6416e-04 - accuracy: 0.1289 - val_loss: 6.0166e-04 - val_accuracy: 0.0126
# Epoch 66/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7553e-04 - accuracy: 0.1289 - val_loss: 8.8355e-04 - val_accuracy: 0.0126
# Epoch 67/300
# 636/636 [==============================] - 2s 3ms/step - loss: 9.6076e-04 - accuracy: 0.1289 - val_loss: 8.3916e-04 - val_accuracy: 0.0126
# Epoch 68/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.7920e-04 - val_accuracy: 0.0126
# Epoch 69/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7231e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 70/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6442e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 71/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7851e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 72/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6074e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 73/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8970e-04 - accuracy: 0.1289 - val_loss: 0.0033 - val_accuracy: 0.0126
# Epoch 74/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8042e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 75/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5638e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 76/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6697e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 77/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6021e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 78/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4023e-04 - accuracy: 0.1289 - val_loss: 7.8786e-04 - val_accuracy: 0.0126
# Epoch 79/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7498e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 80/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6195e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 81/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5521e-04 - accuracy: 0.1289 - val_loss: 7.8623e-04 - val_accuracy: 0.0126
# Epoch 82/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5810e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 83/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6911e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 84/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6238e-04 - accuracy: 0.1289 - val_loss: 0.0045 - val_accuracy: 0.0126
# Epoch 85/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9088e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 86/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5313e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 87/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5075e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 88/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1704e-04 - accuracy: 0.1289 - val_loss: 0.0056 - val_accuracy: 0.0126
# Epoch 89/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5786e-04 - accuracy: 0.1289 - val_loss: 0.0029 - val_accuracy: 0.0126
# Epoch 90/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5883e-04 - accuracy: 0.1289 - val_loss: 0.0027 - val_accuracy: 0.0126
# Epoch 91/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3200e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 92/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5011e-04 - accuracy: 0.1289 - val_loss: 0.0047 - val_accuracy: 0.0126
# Epoch 93/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5025e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 94/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4104e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 95/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7110e-04 - accuracy: 0.1289 - val_loss: 7.5069e-04 - val_accuracy: 0.0126
# Epoch 96/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4704e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 97/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.8450e-04 - accuracy: 0.1289 - val_loss: 8.1517e-04 - val_accuracy: 0.0126
# Epoch 98/300
# 636/636 [==============================] - 2s 3ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 9.4061e-04 - val_accuracy: 0.0126
# Epoch 99/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6934e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 100/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4145e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 101/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7583e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 102/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2827e-04 - accuracy: 0.1289 - val_loss: 7.3599e-04 - val_accuracy: 0.0126
# Epoch 103/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4476e-04 - accuracy: 0.1289 - val_loss: 9.0400e-04 - val_accuracy: 0.0126
# Epoch 104/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6037e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 105/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5465e-04 - accuracy: 0.1289 - val_loss: 0.0068 - val_accuracy: 0.0126
# Epoch 106/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8224e-04 - accuracy: 0.1289 - val_loss: 0.0031 - val_accuracy: 0.0126
# Epoch 107/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6149e-04 - accuracy: 0.1289 - val_loss: 0.0041 - val_accuracy: 0.0126
# Epoch 108/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3404e-04 - accuracy: 0.1289 - val_loss: 0.0040 - val_accuracy: 0.0126
# Epoch 109/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3378e-04 - accuracy: 0.1289 - val_loss: 8.9028e-04 - val_accuracy: 0.0126
# Epoch 110/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2141e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 111/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1916e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 112/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4242e-04 - accuracy: 0.1289 - val_loss: 6.6494e-04 - val_accuracy: 0.0126
# Epoch 113/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5780e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 114/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4540e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 115/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6072e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 116/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5032e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 117/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7659e-04 - accuracy: 0.1289 - val_loss: 0.0027 - val_accuracy: 0.0126
# Epoch 118/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6435e-04 - accuracy: 0.1289 - val_loss: 6.7628e-04 - val_accuracy: 0.0126
# Epoch 119/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2977e-04 - accuracy: 0.1289 - val_loss: 8.0019e-04 - val_accuracy: 0.0126
# Epoch 120/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6273e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 121/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4653e-04 - accuracy: 0.1289 - val_loss: 8.9699e-04 - val_accuracy: 0.0126
# Epoch 122/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2559e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 123/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4615e-04 - accuracy: 0.1289 - val_loss: 7.8787e-04 - val_accuracy: 0.0126
# Epoch 124/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6321e-04 - accuracy: 0.1289 - val_loss: 6.7851e-04 - val_accuracy: 0.0126
# Epoch 125/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3977e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 126/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3149e-04 - accuracy: 0.1289 - val_loss: 0.0029 - val_accuracy: 0.0126
# Epoch 127/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7241e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 128/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2672e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 129/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4028e-04 - accuracy: 0.1289 - val_loss: 0.0035 - val_accuracy: 0.0126
# Epoch 130/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3787e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 131/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4112e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 132/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4490e-04 - accuracy: 0.1289 - val_loss: 0.0055 - val_accuracy: 0.0126
# Epoch 133/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3755e-04 - accuracy: 0.1289 - val_loss: 7.7272e-04 - val_accuracy: 0.0126
# Epoch 134/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3680e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 135/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5463e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 136/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4549e-04 - accuracy: 0.1289 - val_loss: 0.0027 - val_accuracy: 0.0126
# Epoch 137/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6502e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 138/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3620e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 139/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3613e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 140/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.3373e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 141/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3854e-04 - accuracy: 0.1289 - val_loss: 9.3756e-04 - val_accuracy: 0.0126
# Epoch 142/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3743e-04 - accuracy: 0.1289 - val_loss: 0.0094 - val_accuracy: 0.0126
# Epoch 143/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5664e-04 - accuracy: 0.1289 - val_loss: 0.0033 - val_accuracy: 0.0126
# Epoch 144/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3629e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 145/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.3755e-04 - accuracy: 0.1289 - val_loss: 8.1435e-04 - val_accuracy: 0.0126
# Epoch 146/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0676e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 147/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1985e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 148/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5037e-04 - accuracy: 0.1289 - val_loss: 8.6830e-04 - val_accuracy: 0.0126
# Epoch 149/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5661e-04 - accuracy: 0.1289 - val_loss: 0.0057 - val_accuracy: 0.0126
# Epoch 150/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4127e-04 - accuracy: 0.1289 - val_loss: 7.0053e-04 - val_accuracy: 0.0126
# Epoch 151/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2995e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 152/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2876e-04 - accuracy: 0.1289 - val_loss: 6.9723e-04 - val_accuracy: 0.0126
# Epoch 153/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3873e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 154/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4816e-04 - accuracy: 0.1289 - val_loss: 9.3163e-04 - val_accuracy: 0.0126
# Epoch 155/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4153e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 156/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3698e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 157/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4967e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 158/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0491e-04 - accuracy: 0.1289 - val_loss: 9.7784e-04 - val_accuracy: 0.0126
# Epoch 159/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4797e-04 - accuracy: 0.1289 - val_loss: 6.8281e-04 - val_accuracy: 0.0126
# Epoch 160/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4799e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 161/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2996e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 162/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3674e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 163/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3467e-04 - accuracy: 0.1289 - val_loss: 7.0249e-04 - val_accuracy: 0.0126
# Epoch 164/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1860e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 165/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9541e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 166/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5257e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 167/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4078e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 168/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2071e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 169/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7872e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 170/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4664e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 171/300
# 636/636 [==============================] - 2s 3ms/step - loss: 9.2339e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 172/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2676e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 173/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1754e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 174/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0640e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 175/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4049e-04 - accuracy: 0.1289 - val_loss: 7.9413e-04 - val_accuracy: 0.0126
# Epoch 176/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2927e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 177/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3475e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 178/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2046e-04 - accuracy: 0.1289 - val_loss: 0.0048 - val_accuracy: 0.0126
# Epoch 179/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3857e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 180/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0542e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 181/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.3402e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 182/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3664e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 183/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3669e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 184/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1587e-04 - accuracy: 0.1289 - val_loss: 0.0032 - val_accuracy: 0.0126
# Epoch 185/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2081e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 186/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4300e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 187/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3559e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 188/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2046e-04 - accuracy: 0.1289 - val_loss: 0.0026 - val_accuracy: 0.0126
# Epoch 189/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4576e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 190/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5363e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 191/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3396e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 192/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2396e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 193/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2051e-04 - accuracy: 0.1289 - val_loss: 7.0615e-04 - val_accuracy: 0.0126
# Epoch 194/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2289e-04 - accuracy: 0.1289 - val_loss: 7.6121e-04 - val_accuracy: 0.0126
# Epoch 195/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2110e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 196/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1431e-04 - accuracy: 0.1289 - val_loss: 7.8389e-04 - val_accuracy: 0.0126
# Epoch 197/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1977e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 198/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3095e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 199/300
# 636/636 [==============================] - 2s 4ms/step - loss: 8.9889e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 200/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0874e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 201/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0710e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 202/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1278e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 203/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1483e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 204/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2319e-04 - accuracy: 0.1289 - val_loss: 0.0026 - val_accuracy: 0.0126
# Epoch 205/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3572e-04 - accuracy: 0.1289 - val_loss: 0.0046 - val_accuracy: 0.0126
# Epoch 206/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3654e-04 - accuracy: 0.1289 - val_loss: 0.0031 - val_accuracy: 0.0126
# Epoch 207/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4751e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 208/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1561e-04 - accuracy: 0.1289 - val_loss: 0.0041 - val_accuracy: 0.0126
# Epoch 209/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1836e-04 - accuracy: 0.1289 - val_loss: 0.0050 - val_accuracy: 0.0126
# Epoch 210/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2920e-04 - accuracy: 0.1289 - val_loss: 7.5451e-04 - val_accuracy: 0.0126
# Epoch 211/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2715e-04 - accuracy: 0.1289 - val_loss: 0.0036 - val_accuracy: 0.0126
# Epoch 212/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1709e-04 - accuracy: 0.1289 - val_loss: 0.0060 - val_accuracy: 0.0126
# Epoch 213/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1880e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 214/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3990e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 215/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2204e-04 - accuracy: 0.1289 - val_loss: 8.0051e-04 - val_accuracy: 0.0126
# Epoch 216/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2816e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 217/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2433e-04 - accuracy: 0.1289 - val_loss: 0.0031 - val_accuracy: 0.0126
# Epoch 218/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9824e-04 - accuracy: 0.1289 - val_loss: 8.3860e-04 - val_accuracy: 0.0126
# Epoch 219/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1820e-04 - accuracy: 0.1289 - val_loss: 8.6327e-04 - val_accuracy: 0.0126
# Epoch 220/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2989e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 221/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0587e-04 - accuracy: 0.1289 - val_loss: 8.2445e-04 - val_accuracy: 0.0126
# Epoch 222/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2423e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 223/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2945e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 224/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1940e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 225/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1637e-04 - accuracy: 0.1289 - val_loss: 8.4007e-04 - val_accuracy: 0.0126
# Epoch 226/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1174e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 227/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0470e-04 - accuracy: 0.1289 - val_loss: 7.3598e-04 - val_accuracy: 0.0126
# Epoch 228/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1432e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 229/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1583e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 230/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1746e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 231/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.4093e-04 - accuracy: 0.1289 - val_loss: 9.5742e-04 - val_accuracy: 0.0126
# Epoch 232/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.2112e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 233/300
# 636/636 [==============================] - 5s 8ms/step - loss: 9.2633e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 234/300
# 636/636 [==============================] - 5s 9ms/step - loss: 9.2114e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 235/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3853e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 236/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1706e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 237/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1689e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 238/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3291e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 239/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4069e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 240/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1701e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 241/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3655e-04 - accuracy: 0.1289 - val_loss: 8.9368e-04 - val_accuracy: 0.0126
# Epoch 242/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2501e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 243/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1005e-04 - accuracy: 0.1289 - val_loss: 9.5451e-04 - val_accuracy: 0.0126
# Epoch 244/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3645e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 245/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1071e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 246/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3551e-04 - accuracy: 0.1289 - val_loss: 0.0037 - val_accuracy: 0.0126
# Epoch 247/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3160e-04 - accuracy: 0.1289 - val_loss: 0.0030 - val_accuracy: 0.0126
# Epoch 248/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1127e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 249/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1639e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 250/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2926e-04 - accuracy: 0.1289 - val_loss: 8.2923e-04 - val_accuracy: 0.0126
# Epoch 251/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1674e-04 - accuracy: 0.1289 - val_loss: 0.0048 - val_accuracy: 0.0126
# Epoch 252/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0119e-04 - accuracy: 0.1289 - val_loss: 0.0041 - val_accuracy: 0.0126
# Epoch 253/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1335e-04 - accuracy: 0.1289 - val_loss: 0.0036 - val_accuracy: 0.0126
# Epoch 254/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1879e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 255/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2996e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 256/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2210e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 257/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0202e-04 - accuracy: 0.1289 - val_loss: 8.1982e-04 - val_accuracy: 0.0126
# Epoch 258/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3402e-04 - accuracy: 0.1289 - val_loss: 9.3754e-04 - val_accuracy: 0.0126
# Epoch 259/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2067e-04 - accuracy: 0.1289 - val_loss: 0.0032 - val_accuracy: 0.0126
# Epoch 260/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1755e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 261/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.2390e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 262/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.2327e-04 - accuracy: 0.1289 - val_loss: 8.4013e-04 - val_accuracy: 0.0126
# Epoch 263/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1401e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 264/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.3259e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 265/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2519e-04 - accuracy: 0.1289 - val_loss: 0.0035 - val_accuracy: 0.0126
# Epoch 266/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1854e-04 - accuracy: 0.1289 - val_loss: 0.0041 - val_accuracy: 0.0126
# Epoch 267/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0679e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 268/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.2631e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 269/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0654e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 270/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1235e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 271/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9718e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 272/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.0115e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 273/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2102e-04 - accuracy: 0.1289 - val_loss: 0.0040 - val_accuracy: 0.0126
# Epoch 274/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3273e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 275/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2468e-04 - accuracy: 0.1289 - val_loss: 0.0035 - val_accuracy: 0.0126
# Epoch 276/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0708e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 277/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9596e-04 - accuracy: 0.1289 - val_loss: 9.0141e-04 - val_accuracy: 0.0126
# Epoch 278/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0241e-04 - accuracy: 0.1289 - val_loss: 0.0031 - val_accuracy: 0.0126
# Epoch 279/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1302e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 280/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1709e-04 - accuracy: 0.1289 - val_loss: 0.0055 - val_accuracy: 0.0126
# Epoch 281/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9894e-04 - accuracy: 0.1289 - val_loss: 0.0044 - val_accuracy: 0.0126
# Epoch 282/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1948e-04 - accuracy: 0.1289 - val_loss: 0.0030 - val_accuracy: 0.0126
# Epoch 283/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0850e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 284/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3602e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 285/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1541e-04 - accuracy: 0.1289 - val_loss: 0.0047 - val_accuracy: 0.0126
# Epoch 286/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1992e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 287/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1998e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 288/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8905e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 289/300
# 636/636 [==============================] - 3s 5ms/step - loss: 8.9405e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 290/300
# 636/636 [==============================] - 3s 5ms/step - loss: 8.9051e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 291/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1983e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 292/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1768e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 293/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.0628e-04 - accuracy: 0.1289 - val_loss: 8.3512e-04 - val_accuracy: 0.0126
# Epoch 294/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2550e-04 - accuracy: 0.1289 - val_loss: 0.0032 - val_accuracy: 0.0126
# Epoch 295/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2385e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 296/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1504e-04 - accuracy: 0.1289 - val_loss: 0.0029 - val_accuracy: 0.0126
# Epoch 297/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1689e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 298/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9008e-04 - accuracy: 0.1289 - val_loss: 0.0026 - val_accuracy: 0.0126
# Epoch 299/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9141e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 300/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1318e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# INFO:tensorflow:Assets written to: lstm/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7eff6f8014d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
losses_lstm = model.history.history['loss']
fig = plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(range(len(losses_lstm)),losses_lstm)
plt.grid()
fig.savefig('losses lstm.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
model.summary()
model.save('LSTM.h5')
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 200)               161600
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions
print(f'trainPredict {trainPredict.shape}')
print(f'trainY {trainY.shape}')
print(f'testPredict {testPredict.shape}')
print(f'testY {testY.shape}')
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# trainPredict (795, 1)
# trainY (795,)
# testPredict (39, 1)
# testY (39,)

# %%
#Mean Squared Error
trainScore_MSE = mean_squared_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore_MSE))
testScore_MSE = mean_squared_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MSE' % (testScore_MSE))
# calculate root mean squared error
trainScore_RMSE = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore_RMSE))
testScore_RMSE = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore_RMSE))
#  Mean Absolute Error
trainScore_MAE = mean_absolute_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAE' % (trainScore_MAE))
testScore_MAE = mean_absolute_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAE' % (testScore_MAE))
#  Mean Absolute Percentage Error
trainScore_MAPE = mean_absolute_percentage_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAPE' % (trainScore_MAPE))
testScore_MAPE = mean_absolute_percentage_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAPE' % (testScore_MAPE))

#  Coefficient of Determination-R2 score
trainScore_r2 = r2_score(trainY[0], trainPredict[:,0])
print('Train Score: %.2f r2' % (trainScore_r2))
testScore_r2= r2_score(testY[0], testPredict[:,0])
print('Test Score: %.2f r2' % (testScore_r2))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# Out:
# Train Score: 1614.69 MSE
# Test Score: 922.83 MSE
# Train Score: 40.18 RMSE
# Test Score: 30.38 RMSE
# Train Score: 28.81 MAE
# Test Score: 25.95 MAE
# Train Score: 4003881136017660.50 MAPE
# Test Score: 0.08 MAPE
# Train Score: 0.99 r2
# Test Score: 0.92 r2

# %%
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
fig = plt.figure(figsize=(12,4))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title(plot_title) 
plt.legend([Implementation, 'training','testing'], loc='upper left')
plt.xlabel(f'Time in {Time}')
plt.ylabel(Implementation)
plt.grid()
plt.show()
fig.savefig('final.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')

# %%
# predictions = model.predict() #this creates states
future_x = []
future_y = []
currentStep = dataset[-look_back:] #last step from the previous prediction
# model.reset_states()
for i in range(Forecasting_days):
    predicted = model.predict(currentStep.reshape(1,look_back,1)) #get the next step
    future_x.append(currentStep) #store the future steps \
    future_y.append(predicted)
    future_y[i] = np.reshape(scaler.inverse_transform(future_y[i]), 1)
    currentStep = np.concatenate((currentStep[1:], predicted), axis=0).astype(np.float32)
future_predictions_x = pd.DataFrame(np.array(future_x).reshape(Forecasting_days,look_back))
future_predictions_y = pd.DataFrame(future_y,columns=['Future'])
# print(future_predictions_x)
print(future_predictions_y)
# Out:
#        Future
# 0  205.308258
# 1  196.795959
# 2  194.280411
# 3  186.814667
# 4  178.578430
# 5  166.814911
# 6  154.883316
# 7  144.736786
# 8  136.630753
# 9  130.461472

# %%
file1 = open('Accuracy.txt', 'w')
file1.write(f'Train Score r2 %.2f : {trainScore_r2}\n Test Score r2 %.2f r2: {testScore_r2}\n Train Score MSE: {trainScore_MSE}\n Test Score MSE: {testScore_MSE}\n Train Score RMSE: {trainScore_RMSE}\n test Score RMSE: {testScore_RMSE}\n Train Score MAE: {trainScore_MAE}\n Test Score MAE: {testScore_MAE}\n Train Score MAPE: {trainScore_MAPE}\n Test Score MAPE: {testScore_MAPE}')
file1.close()

# %%
file2 = open('Prediction.txt', 'w')
file2.write(f'Prediction:\n {future_predictions_y}')
file2.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

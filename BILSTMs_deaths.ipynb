# %% [markdown]
# <a href="https://colab.research.google.com/github/abotalebmostafa11/DL-System/blob/main/BILSTMs_deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-903025ca-d18c-4bde-9e2e-df427135481a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-903025ca-d18c-4bde-9e2e-df427135481a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Deaths.csv to Deaths.csv

# %%
# LSTM for Forecasting Covid 19 problem In Russian Fderation
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.layers import Dense,RepeatVector,LSTM,Dropout,GRU,Dense,SimpleRNN,Embedding 
from keras.callbacks import ModelCheckpoint, TensorBoard, Callback, EarlyStopping
from tensorflow.keras.layers import Flatten, Conv1D, MaxPooling1D
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Bidirectional, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, TimeDistributed
from keras.utils.vis_utils import plot_model
from keras.models import Model, load_model
from keras.layers import Dense, Softmax
from sklearn.metrics import r2_score
from keras.models import Sequential
import matplotlib.pyplot as plt
from pandas import read_csv
from numpy import array
import pandas as pd
import numpy as np
import numpy
import math

# %%
Data_Name="Deaths.csv"
Use_Percent = True
if Use_Percent:
    train_Percent = 0.95
else:
    Testing_Rows = 0
Forecasting_days = 10 # how many days that you want to forecast?
create_new_model = True
Time="days"
Implementation="Covid 19 daily deaths Cases in Russia"
plot_title="Modelling and forecasting deaths cases in Russia by using BILSTMs (stacked bilstm) Model "
Model_Name="stacked bilstm"

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv(Data_Name, usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
if Use_Percent:
    train_size = int(len(dataset) * (train_Percent))
    test_size = len(dataset) - train_size
    pass
else:
    train_size = len(dataset) - Testing_Rows
    test_size = Testing_Rows
    pass

#train_size = int(len(dataset) * train_Percent)
#test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back=int(input('LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:'))
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
#trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
#testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = numpy.reshape(testX, (testX.shape[0], look_back, 1))
trainY = trainY.T
testY = testY.T
print(f'trainX = {trainX.shape}')
print(f'trainY = {trainY.shape}')
print(f'testX = {testX.shape}')
print(f'testY = {testY.shape}')
# Out:
# LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:2
# trainX = (795, 2, 1)
# trainY = (795,)
# testX = (39, 2, 1)
# testY = (39,)

# %%
# %%
if create_new_model:
    model = Sequential()
    n_input = 12
    n_features= 1
    generator = TimeseriesGenerator(dataset, dataset, length=n_input, batch_size=n_features)
    early_stop = EarlyStopping(monitor = "loss", mode = "min", patience = 7)
    #for layer in Model_Name:
    if Model_Name.lower() == "bilstm":
        # create and fit the BILSTM for Regression network (bilstm)
        print('Machine learning software = => create and fit the BILSTM for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN,activation=activation, input_shape=(look_back,1))))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked bilstm":
        # create and fit the BILSTM stack network (stacked bilstm)
        print('Machine learning software = => create and fit the stacked bilstm for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back,1))))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1))))
        model.add(Bidirectional(LSTM(20)))
        model.add(Dense(1))
    if  Model_Name.lower() == "convlstms":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstms)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(Conv1D(filters=128, kernel_size=2, activation=activation))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(RepeatVector(30))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Bidirectional(LSTM(128, activation=activation)))
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "conv":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "lstm":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked lstm":
        print('Machine learning software = => create and fit the stacked lstm for Regression network...')
        # create and fit the Stacked LSTM for Regression network (stacked lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(20))
        model.add(Dense(1))     
    if  Model_Name.lower() == "gru":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(GRU(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    model.compile(loss=inputloss_function, optimizer=inputoptimizer_name,metrics=['accuracy'])
    history =model.fit(trainX, trainY, epochs=N_epochs, batch_size=1, verbose=True,validation_split=0.2, shuffle=True)
    print(history.history.keys())
    #  "Accuracy"
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('Accuracy.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    # "Loss" # plot train and validation loss
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model train vs validation loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('plot train and validation loss.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    model.save(Model_Name)
else:
    model = load_model(Model_Name)
    model.summary()
# Out:
# Machine learning software = => create and fit the stacked bilstm for Regression network...
# Enter the number of epochs:300
# Enter the Loss Function:MeanSquaredError
# Enter the Optimizer Name:adam
# Enter the activation function name:relu
# Enter the number of neurans:200
# Epoch 1/300
# 636/636 [==============================] - 12s 11ms/step - loss: 0.0050 - accuracy: 0.1289 - val_loss: 0.0040 - val_accuracy: 0.0126
# Epoch 2/300
# 636/636 [==============================] - 6s 9ms/step - loss: 0.0016 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 3/300
# 636/636 [==============================] - 7s 11ms/step - loss: 0.0019 - accuracy: 0.1289 - val_loss: 0.0042 - val_accuracy: 0.0126
# Epoch 4/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0016 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 5/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0016 - accuracy: 0.1289 - val_loss: 0.0051 - val_accuracy: 0.0126
# Epoch 6/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0016 - accuracy: 0.1289 - val_loss: 0.0030 - val_accuracy: 0.0126
# Epoch 7/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0016 - accuracy: 0.1289 - val_loss: 0.0186 - val_accuracy: 0.0126
# Epoch 8/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0098 - val_accuracy: 0.0126
# Epoch 9/300
# 636/636 [==============================] - 7s 11ms/step - loss: 0.0015 - accuracy: 0.1289 - val_loss: 0.0247 - val_accuracy: 0.0126
# Epoch 10/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0076 - val_accuracy: 0.0126
# Epoch 11/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0102 - val_accuracy: 0.0126
# Epoch 12/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0015 - accuracy: 0.1289 - val_loss: 0.0121 - val_accuracy: 0.0126
# Epoch 13/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0145 - val_accuracy: 0.0126
# Epoch 14/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0180 - val_accuracy: 0.0126
# Epoch 15/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0206 - val_accuracy: 0.0126
# Epoch 16/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0209 - val_accuracy: 0.0126
# Epoch 17/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0239 - val_accuracy: 0.0126
# Epoch 18/300
# 636/636 [==============================] - 7s 12ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0191 - val_accuracy: 0.0126
# Epoch 19/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0106 - val_accuracy: 0.0126
# Epoch 20/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0133 - val_accuracy: 0.0126
# Epoch 21/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0185 - val_accuracy: 0.0126
# Epoch 22/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0393 - val_accuracy: 0.0126
# Epoch 23/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0172 - val_accuracy: 0.0126
# Epoch 24/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0308 - val_accuracy: 0.0126
# Epoch 25/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0291 - val_accuracy: 0.0126
# Epoch 26/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0237 - val_accuracy: 0.0126
# Epoch 27/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0187 - val_accuracy: 0.0126
# Epoch 28/300
# 636/636 [==============================] - 7s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0280 - val_accuracy: 0.0126
# Epoch 29/300
# 636/636 [==============================] - 7s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0177 - val_accuracy: 0.0126
# Epoch 30/300
# 636/636 [==============================] - 7s 11ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0200 - val_accuracy: 0.0126
# Epoch 31/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0270 - val_accuracy: 0.0126
# Epoch 32/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0280 - val_accuracy: 0.0126
# Epoch 33/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 34/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0166 - val_accuracy: 0.0126
# Epoch 35/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0218 - val_accuracy: 0.0126
# Epoch 36/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0199 - val_accuracy: 0.0126
# Epoch 37/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0238 - val_accuracy: 0.0126
# Epoch 38/300
# 636/636 [==============================] - 7s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0193 - val_accuracy: 0.0126
# Epoch 39/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0164 - val_accuracy: 0.0126
# Epoch 40/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0240 - val_accuracy: 0.0126
# Epoch 41/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0295 - val_accuracy: 0.0126
# Epoch 42/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0230 - val_accuracy: 0.0126
# Epoch 43/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0158 - val_accuracy: 0.0126
# Epoch 44/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0295 - val_accuracy: 0.0126
# Epoch 45/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0169 - val_accuracy: 0.0126
# Epoch 46/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0155 - val_accuracy: 0.0126
# Epoch 47/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0312 - val_accuracy: 0.0126
# Epoch 48/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0286 - val_accuracy: 0.0126
# Epoch 49/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0350 - val_accuracy: 0.0126
# Epoch 50/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0215 - val_accuracy: 0.0126
# Epoch 51/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0262 - val_accuracy: 0.0126
# Epoch 52/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0325 - val_accuracy: 0.0126
# Epoch 53/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0274 - val_accuracy: 0.0126
# Epoch 54/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0225 - val_accuracy: 0.0126
# Epoch 55/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0240 - val_accuracy: 0.0126
# Epoch 56/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0206 - val_accuracy: 0.0126
# Epoch 57/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0200 - val_accuracy: 0.0126
# Epoch 58/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0226 - val_accuracy: 0.0126
# Epoch 59/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8207e-04 - accuracy: 0.1289 - val_loss: 0.0191 - val_accuracy: 0.0126
# Epoch 60/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0260 - val_accuracy: 0.0126
# Epoch 61/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8024e-04 - accuracy: 0.1289 - val_loss: 0.0216 - val_accuracy: 0.0126
# Epoch 62/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0220 - val_accuracy: 0.0126
# Epoch 63/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8471e-04 - accuracy: 0.1289 - val_loss: 0.0225 - val_accuracy: 0.0126
# Epoch 64/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.6630e-04 - accuracy: 0.1289 - val_loss: 0.0294 - val_accuracy: 0.0126
# Epoch 65/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0187 - val_accuracy: 0.0126
# Epoch 66/300
# 636/636 [==============================] - 7s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0191 - val_accuracy: 0.0126
# Epoch 67/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0153 - val_accuracy: 0.0126
# Epoch 68/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.9831e-04 - accuracy: 0.1289 - val_loss: 0.0179 - val_accuracy: 0.0126
# Epoch 69/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0173 - val_accuracy: 0.0126
# Epoch 70/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8494e-04 - accuracy: 0.1289 - val_loss: 0.0189 - val_accuracy: 0.0126
# Epoch 71/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8330e-04 - accuracy: 0.1289 - val_loss: 0.0114 - val_accuracy: 0.0126
# Epoch 72/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5125e-04 - accuracy: 0.1289 - val_loss: 0.0157 - val_accuracy: 0.0126
# Epoch 73/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0159 - val_accuracy: 0.0126
# Epoch 74/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8295e-04 - accuracy: 0.1289 - val_loss: 0.0162 - val_accuracy: 0.0126
# Epoch 75/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7046e-04 - accuracy: 0.1289 - val_loss: 0.0172 - val_accuracy: 0.0126
# Epoch 76/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8997e-04 - accuracy: 0.1289 - val_loss: 0.0156 - val_accuracy: 0.0126
# Epoch 77/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.8737e-04 - accuracy: 0.1289 - val_loss: 0.0137 - val_accuracy: 0.0126
# Epoch 78/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5760e-04 - accuracy: 0.1289 - val_loss: 0.0150 - val_accuracy: 0.0126
# Epoch 79/300
# 636/636 [==============================] - 6s 10ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0138 - val_accuracy: 0.0126
# Epoch 80/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5840e-04 - accuracy: 0.1289 - val_loss: 0.0151 - val_accuracy: 0.0126
# Epoch 81/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8979e-04 - accuracy: 0.1289 - val_loss: 0.0174 - val_accuracy: 0.0126
# Epoch 82/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2860e-04 - accuracy: 0.1289 - val_loss: 0.0161 - val_accuracy: 0.0126
# Epoch 83/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5504e-04 - accuracy: 0.1289 - val_loss: 0.0163 - val_accuracy: 0.0126
# Epoch 84/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8146e-04 - accuracy: 0.1289 - val_loss: 0.0127 - val_accuracy: 0.0126
# Epoch 85/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7964e-04 - accuracy: 0.1289 - val_loss: 0.0179 - val_accuracy: 0.0126
# Epoch 86/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.9735e-04 - accuracy: 0.1289 - val_loss: 0.0132 - val_accuracy: 0.0126
# Epoch 87/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.8221e-04 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 88/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4684e-04 - accuracy: 0.1289 - val_loss: 0.0115 - val_accuracy: 0.0126
# Epoch 89/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.6241e-04 - accuracy: 0.1289 - val_loss: 0.0154 - val_accuracy: 0.0126
# Epoch 90/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.9672e-04 - accuracy: 0.1289 - val_loss: 0.0137 - val_accuracy: 0.0126
# Epoch 91/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.6239e-04 - accuracy: 0.1289 - val_loss: 0.0157 - val_accuracy: 0.0126
# Epoch 92/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5493e-04 - accuracy: 0.1289 - val_loss: 0.0128 - val_accuracy: 0.0126
# Epoch 93/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5256e-04 - accuracy: 0.1289 - val_loss: 0.0134 - val_accuracy: 0.0126
# Epoch 94/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.6204e-04 - accuracy: 0.1289 - val_loss: 0.0121 - val_accuracy: 0.0126
# Epoch 95/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5717e-04 - accuracy: 0.1289 - val_loss: 0.0154 - val_accuracy: 0.0126
# Epoch 96/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3655e-04 - accuracy: 0.1289 - val_loss: 0.0159 - val_accuracy: 0.0126
# Epoch 97/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1322e-04 - accuracy: 0.1289 - val_loss: 0.0159 - val_accuracy: 0.0126
# Epoch 98/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5825e-04 - accuracy: 0.1289 - val_loss: 0.0230 - val_accuracy: 0.0126
# Epoch 99/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5595e-04 - accuracy: 0.1289 - val_loss: 0.0162 - val_accuracy: 0.0126
# Epoch 100/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7212e-04 - accuracy: 0.1289 - val_loss: 0.0176 - val_accuracy: 0.0126
# Epoch 101/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.5568e-04 - accuracy: 0.1289 - val_loss: 0.0187 - val_accuracy: 0.0126
# Epoch 102/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.6595e-04 - accuracy: 0.1289 - val_loss: 0.0223 - val_accuracy: 0.0126
# Epoch 103/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4756e-04 - accuracy: 0.1289 - val_loss: 0.0158 - val_accuracy: 0.0126
# Epoch 104/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7757e-04 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 105/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7497e-04 - accuracy: 0.1289 - val_loss: 0.0187 - val_accuracy: 0.0126
# Epoch 106/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7823e-04 - accuracy: 0.1289 - val_loss: 0.0190 - val_accuracy: 0.0126
# Epoch 107/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2632e-04 - accuracy: 0.1289 - val_loss: 0.0179 - val_accuracy: 0.0126
# Epoch 108/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.6136e-04 - accuracy: 0.1289 - val_loss: 0.0204 - val_accuracy: 0.0126
# Epoch 109/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3927e-04 - accuracy: 0.1289 - val_loss: 0.0203 - val_accuracy: 0.0126
# Epoch 110/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4302e-04 - accuracy: 0.1289 - val_loss: 0.0217 - val_accuracy: 0.0126
# Epoch 111/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5050e-04 - accuracy: 0.1289 - val_loss: 0.0208 - val_accuracy: 0.0126
# Epoch 112/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3479e-04 - accuracy: 0.1289 - val_loss: 0.0201 - val_accuracy: 0.0126
# Epoch 113/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.5132e-04 - accuracy: 0.1289 - val_loss: 0.0191 - val_accuracy: 0.0126
# Epoch 114/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2744e-04 - accuracy: 0.1289 - val_loss: 0.0190 - val_accuracy: 0.0126
# Epoch 115/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.6028e-04 - accuracy: 0.1289 - val_loss: 0.0232 - val_accuracy: 0.0126
# Epoch 116/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0977e-04 - accuracy: 0.1289 - val_loss: 0.0173 - val_accuracy: 0.0126
# Epoch 117/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1496e-04 - accuracy: 0.1289 - val_loss: 0.0234 - val_accuracy: 0.0126
# Epoch 118/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.4464e-04 - accuracy: 0.1289 - val_loss: 0.0196 - val_accuracy: 0.0126
# Epoch 119/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4927e-04 - accuracy: 0.1289 - val_loss: 0.0212 - val_accuracy: 0.0126
# Epoch 120/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3463e-04 - accuracy: 0.1289 - val_loss: 0.0208 - val_accuracy: 0.0126
# Epoch 121/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2899e-04 - accuracy: 0.1289 - val_loss: 0.0233 - val_accuracy: 0.0126
# Epoch 122/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.5695e-04 - accuracy: 0.1289 - val_loss: 0.0252 - val_accuracy: 0.0126
# Epoch 123/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3433e-04 - accuracy: 0.1289 - val_loss: 0.0287 - val_accuracy: 0.0126
# Epoch 124/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2850e-04 - accuracy: 0.1289 - val_loss: 0.0233 - val_accuracy: 0.0126
# Epoch 125/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3158e-04 - accuracy: 0.1289 - val_loss: 0.0231 - val_accuracy: 0.0126
# Epoch 126/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.7350e-04 - accuracy: 0.1289 - val_loss: 0.0279 - val_accuracy: 0.0126
# Epoch 127/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3209e-04 - accuracy: 0.1289 - val_loss: 0.0240 - val_accuracy: 0.0126
# Epoch 128/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.3540e-04 - accuracy: 0.1289 - val_loss: 0.0257 - val_accuracy: 0.0126
# Epoch 129/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9787e-04 - accuracy: 0.1289 - val_loss: 0.0278 - val_accuracy: 0.0126
# Epoch 130/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4402e-04 - accuracy: 0.1289 - val_loss: 0.0270 - val_accuracy: 0.0126
# Epoch 131/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2033e-04 - accuracy: 0.1289 - val_loss: 0.0302 - val_accuracy: 0.0126
# Epoch 132/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2789e-04 - accuracy: 0.1289 - val_loss: 0.0259 - val_accuracy: 0.0126
# Epoch 133/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9151e-04 - accuracy: 0.1289 - val_loss: 0.0217 - val_accuracy: 0.0126
# Epoch 134/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4279e-04 - accuracy: 0.1289 - val_loss: 0.0256 - val_accuracy: 0.0126
# Epoch 135/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1218e-04 - accuracy: 0.1289 - val_loss: 0.0236 - val_accuracy: 0.0126
# Epoch 136/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.6607e-04 - accuracy: 0.1289 - val_loss: 0.0259 - val_accuracy: 0.0126
# Epoch 137/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9128e-04 - accuracy: 0.1289 - val_loss: 0.0285 - val_accuracy: 0.0126
# Epoch 138/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.3660e-04 - accuracy: 0.1289 - val_loss: 0.0273 - val_accuracy: 0.0126
# Epoch 139/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9651e-04 - accuracy: 0.1289 - val_loss: 0.0262 - val_accuracy: 0.0126
# Epoch 140/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9544e-04 - accuracy: 0.1289 - val_loss: 0.0246 - val_accuracy: 0.0126
# Epoch 141/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1847e-04 - accuracy: 0.1289 - val_loss: 0.0264 - val_accuracy: 0.0126
# Epoch 142/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.5053e-04 - accuracy: 0.1289 - val_loss: 0.0279 - val_accuracy: 0.0126
# Epoch 143/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1162e-04 - accuracy: 0.1289 - val_loss: 0.0222 - val_accuracy: 0.0126
# Epoch 144/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0908e-04 - accuracy: 0.1289 - val_loss: 0.0256 - val_accuracy: 0.0126
# Epoch 145/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2279e-04 - accuracy: 0.1289 - val_loss: 0.0212 - val_accuracy: 0.0126
# Epoch 146/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1976e-04 - accuracy: 0.1289 - val_loss: 0.0231 - val_accuracy: 0.0126
# Epoch 147/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8208e-04 - accuracy: 0.1289 - val_loss: 0.0244 - val_accuracy: 0.0126
# Epoch 148/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4687e-04 - accuracy: 0.1289 - val_loss: 0.0291 - val_accuracy: 0.0126
# Epoch 149/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1161e-04 - accuracy: 0.1289 - val_loss: 0.0208 - val_accuracy: 0.0126
# Epoch 150/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0809e-04 - accuracy: 0.1289 - val_loss: 0.0263 - val_accuracy: 0.0126
# Epoch 151/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1990e-04 - accuracy: 0.1289 - val_loss: 0.0209 - val_accuracy: 0.0126
# Epoch 152/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0014e-04 - accuracy: 0.1289 - val_loss: 0.0199 - val_accuracy: 0.0126
# Epoch 153/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9685e-04 - accuracy: 0.1289 - val_loss: 0.0210 - val_accuracy: 0.0126
# Epoch 154/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.0696e-04 - accuracy: 0.1289 - val_loss: 0.0218 - val_accuracy: 0.0126
# Epoch 155/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1555e-04 - accuracy: 0.1289 - val_loss: 0.0208 - val_accuracy: 0.0126
# Epoch 156/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9605e-04 - accuracy: 0.1289 - val_loss: 0.0216 - val_accuracy: 0.0126
# Epoch 157/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.0691e-04 - accuracy: 0.1289 - val_loss: 0.0235 - val_accuracy: 0.0126
# Epoch 158/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.8924e-04 - accuracy: 0.1289 - val_loss: 0.0254 - val_accuracy: 0.0126
# Epoch 159/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8843e-04 - accuracy: 0.1289 - val_loss: 0.0248 - val_accuracy: 0.0126
# Epoch 160/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.2525e-04 - accuracy: 0.1289 - val_loss: 0.0294 - val_accuracy: 0.0126
# Epoch 161/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2336e-04 - accuracy: 0.1289 - val_loss: 0.0211 - val_accuracy: 0.0126
# Epoch 162/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1775e-04 - accuracy: 0.1289 - val_loss: 0.0222 - val_accuracy: 0.0126
# Epoch 163/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7840e-04 - accuracy: 0.1289 - val_loss: 0.0195 - val_accuracy: 0.0126
# Epoch 164/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1552e-04 - accuracy: 0.1289 - val_loss: 0.0161 - val_accuracy: 0.0126
# Epoch 165/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.7701e-04 - accuracy: 0.1289 - val_loss: 0.0238 - val_accuracy: 0.0126
# Epoch 166/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.4095e-04 - accuracy: 0.1289 - val_loss: 0.0179 - val_accuracy: 0.0126
# Epoch 167/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1341e-04 - accuracy: 0.1289 - val_loss: 0.0194 - val_accuracy: 0.0126
# Epoch 168/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0790e-04 - accuracy: 0.1289 - val_loss: 0.0163 - val_accuracy: 0.0126
# Epoch 169/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0862e-04 - accuracy: 0.1289 - val_loss: 0.0211 - val_accuracy: 0.0126
# Epoch 170/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9859e-04 - accuracy: 0.1289 - val_loss: 0.0187 - val_accuracy: 0.0126
# Epoch 171/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0593e-04 - accuracy: 0.1289 - val_loss: 0.0227 - val_accuracy: 0.0126
# Epoch 172/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.8440e-04 - accuracy: 0.1289 - val_loss: 0.0204 - val_accuracy: 0.0126
# Epoch 173/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.7288e-04 - accuracy: 0.1289 - val_loss: 0.0183 - val_accuracy: 0.0126
# Epoch 174/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1445e-04 - accuracy: 0.1289 - val_loss: 0.0205 - val_accuracy: 0.0126
# Epoch 175/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8617e-04 - accuracy: 0.1289 - val_loss: 0.0191 - val_accuracy: 0.0126
# Epoch 176/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8534e-04 - accuracy: 0.1289 - val_loss: 0.0181 - val_accuracy: 0.0126
# Epoch 177/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.8632e-04 - accuracy: 0.1289 - val_loss: 0.0150 - val_accuracy: 0.0126
# Epoch 178/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.3469e-04 - accuracy: 0.1289 - val_loss: 0.0208 - val_accuracy: 0.0126
# Epoch 179/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7919e-04 - accuracy: 0.1289 - val_loss: 0.0140 - val_accuracy: 0.0126
# Epoch 180/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9187e-04 - accuracy: 0.1289 - val_loss: 0.0200 - val_accuracy: 0.0126
# Epoch 181/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0498e-04 - accuracy: 0.1289 - val_loss: 0.0186 - val_accuracy: 0.0126
# Epoch 182/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.3411e-04 - accuracy: 0.1289 - val_loss: 0.0207 - val_accuracy: 0.0126
# Epoch 183/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0457e-04 - accuracy: 0.1289 - val_loss: 0.0204 - val_accuracy: 0.0126
# Epoch 184/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2901e-04 - accuracy: 0.1289 - val_loss: 0.0213 - val_accuracy: 0.0126
# Epoch 185/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.0130e-04 - accuracy: 0.1289 - val_loss: 0.0170 - val_accuracy: 0.0126
# Epoch 186/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9124e-04 - accuracy: 0.1289 - val_loss: 0.0188 - val_accuracy: 0.0126
# Epoch 187/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8686e-04 - accuracy: 0.1289 - val_loss: 0.0143 - val_accuracy: 0.0126
# Epoch 188/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.5094e-04 - accuracy: 0.1289 - val_loss: 0.0181 - val_accuracy: 0.0126
# Epoch 189/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7895e-04 - accuracy: 0.1289 - val_loss: 0.0167 - val_accuracy: 0.0126
# Epoch 190/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9443e-04 - accuracy: 0.1289 - val_loss: 0.0177 - val_accuracy: 0.0126
# Epoch 191/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7697e-04 - accuracy: 0.1289 - val_loss: 0.0157 - val_accuracy: 0.0126
# Epoch 192/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0995e-04 - accuracy: 0.1289 - val_loss: 0.0183 - val_accuracy: 0.0126
# Epoch 193/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.4937e-04 - accuracy: 0.1289 - val_loss: 0.0164 - val_accuracy: 0.0126
# Epoch 194/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0629e-04 - accuracy: 0.1289 - val_loss: 0.0126 - val_accuracy: 0.0126
# Epoch 195/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.0809e-04 - accuracy: 0.1289 - val_loss: 0.0166 - val_accuracy: 0.0126
# Epoch 196/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1667e-04 - accuracy: 0.1289 - val_loss: 0.0197 - val_accuracy: 0.0126
# Epoch 197/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.8583e-04 - accuracy: 0.1289 - val_loss: 0.0189 - val_accuracy: 0.0126
# Epoch 198/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.8917e-04 - accuracy: 0.1289 - val_loss: 0.0189 - val_accuracy: 0.0126
# Epoch 199/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1529e-04 - accuracy: 0.1289 - val_loss: 0.0211 - val_accuracy: 0.0126
# Epoch 200/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9357e-04 - accuracy: 0.1289 - val_loss: 0.0174 - val_accuracy: 0.0126
# Epoch 201/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9413e-04 - accuracy: 0.1289 - val_loss: 0.0187 - val_accuracy: 0.0126
# Epoch 202/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9057e-04 - accuracy: 0.1289 - val_loss: 0.0196 - val_accuracy: 0.0126
# Epoch 203/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8593e-04 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 204/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8064e-04 - accuracy: 0.1289 - val_loss: 0.0211 - val_accuracy: 0.0126
# Epoch 205/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9591e-04 - accuracy: 0.1289 - val_loss: 0.0163 - val_accuracy: 0.0126
# Epoch 206/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9980e-04 - accuracy: 0.1289 - val_loss: 0.0144 - val_accuracy: 0.0126
# Epoch 207/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9167e-04 - accuracy: 0.1289 - val_loss: 0.0174 - val_accuracy: 0.0126
# Epoch 208/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9111e-04 - accuracy: 0.1289 - val_loss: 0.0190 - val_accuracy: 0.0126
# Epoch 209/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8054e-04 - accuracy: 0.1289 - val_loss: 0.0220 - val_accuracy: 0.0126
# Epoch 210/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8227e-04 - accuracy: 0.1289 - val_loss: 0.0128 - val_accuracy: 0.0126
# Epoch 211/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8457e-04 - accuracy: 0.1289 - val_loss: 0.0147 - val_accuracy: 0.0126
# Epoch 212/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9169e-04 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 213/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9028e-04 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 214/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8835e-04 - accuracy: 0.1289 - val_loss: 0.0133 - val_accuracy: 0.0126
# Epoch 215/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.3596e-04 - accuracy: 0.1289 - val_loss: 0.0140 - val_accuracy: 0.0126
# Epoch 216/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.5418e-04 - accuracy: 0.1289 - val_loss: 0.0156 - val_accuracy: 0.0126
# Epoch 217/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9885e-04 - accuracy: 0.1289 - val_loss: 0.0133 - val_accuracy: 0.0126
# Epoch 218/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.9168e-04 - accuracy: 0.1289 - val_loss: 0.0168 - val_accuracy: 0.0126
# Epoch 219/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7080e-04 - accuracy: 0.1289 - val_loss: 0.0141 - val_accuracy: 0.0126
# Epoch 220/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.0500e-04 - accuracy: 0.1289 - val_loss: 0.0174 - val_accuracy: 0.0126
# Epoch 221/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8094e-04 - accuracy: 0.1289 - val_loss: 0.0165 - val_accuracy: 0.0126
# Epoch 222/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7751e-04 - accuracy: 0.1289 - val_loss: 0.0144 - val_accuracy: 0.0126
# Epoch 223/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9761e-04 - accuracy: 0.1289 - val_loss: 0.0184 - val_accuracy: 0.0126
# Epoch 224/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.5788e-04 - accuracy: 0.1289 - val_loss: 0.0126 - val_accuracy: 0.0126
# Epoch 225/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7713e-04 - accuracy: 0.1289 - val_loss: 0.0138 - val_accuracy: 0.0126
# Epoch 226/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.6952e-04 - accuracy: 0.1289 - val_loss: 0.0154 - val_accuracy: 0.0126
# Epoch 227/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4024e-04 - accuracy: 0.1289 - val_loss: 0.0114 - val_accuracy: 0.0126
# Epoch 228/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8607e-04 - accuracy: 0.1289 - val_loss: 0.0247 - val_accuracy: 0.0126
# Epoch 229/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0982e-04 - accuracy: 0.1289 - val_loss: 0.0182 - val_accuracy: 0.0126
# Epoch 230/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9671e-04 - accuracy: 0.1289 - val_loss: 0.0116 - val_accuracy: 0.0126
# Epoch 231/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.6843e-04 - accuracy: 0.1289 - val_loss: 0.0126 - val_accuracy: 0.0126
# Epoch 232/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7152e-04 - accuracy: 0.1289 - val_loss: 0.0140 - val_accuracy: 0.0126
# Epoch 233/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7230e-04 - accuracy: 0.1289 - val_loss: 0.0122 - val_accuracy: 0.0126
# Epoch 234/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8786e-04 - accuracy: 0.1289 - val_loss: 0.0141 - val_accuracy: 0.0126
# Epoch 235/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8665e-04 - accuracy: 0.1289 - val_loss: 0.0122 - val_accuracy: 0.0126
# Epoch 236/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7259e-04 - accuracy: 0.1289 - val_loss: 0.0144 - val_accuracy: 0.0126
# Epoch 237/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.6734e-04 - accuracy: 0.1289 - val_loss: 0.0178 - val_accuracy: 0.0126
# Epoch 238/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9253e-04 - accuracy: 0.1289 - val_loss: 0.0155 - val_accuracy: 0.0126
# Epoch 239/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.6786e-04 - accuracy: 0.1289 - val_loss: 0.0152 - val_accuracy: 0.0126
# Epoch 240/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8882e-04 - accuracy: 0.1289 - val_loss: 0.0132 - val_accuracy: 0.0126
# Epoch 241/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8213e-04 - accuracy: 0.1289 - val_loss: 0.0120 - val_accuracy: 0.0126
# Epoch 242/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.2892e-04 - accuracy: 0.1289 - val_loss: 0.0094 - val_accuracy: 0.0126
# Epoch 243/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.2046e-04 - accuracy: 0.1289 - val_loss: 0.0133 - val_accuracy: 0.0126
# Epoch 244/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7964e-04 - accuracy: 0.1289 - val_loss: 0.0123 - val_accuracy: 0.0126
# Epoch 245/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5064e-04 - accuracy: 0.1289 - val_loss: 0.0138 - val_accuracy: 0.0126
# Epoch 246/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7950e-04 - accuracy: 0.1289 - val_loss: 0.0117 - val_accuracy: 0.0126
# Epoch 247/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9395e-04 - accuracy: 0.1289 - val_loss: 0.0122 - val_accuracy: 0.0126
# Epoch 248/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.7036e-04 - accuracy: 0.1289 - val_loss: 0.0134 - val_accuracy: 0.0126
# Epoch 249/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7660e-04 - accuracy: 0.1289 - val_loss: 0.0113 - val_accuracy: 0.0126
# Epoch 250/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6216e-04 - accuracy: 0.1289 - val_loss: 0.0083 - val_accuracy: 0.0126
# Epoch 251/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8729e-04 - accuracy: 0.1289 - val_loss: 0.0141 - val_accuracy: 0.0126
# Epoch 252/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6842e-04 - accuracy: 0.1289 - val_loss: 0.0100 - val_accuracy: 0.0126
# Epoch 253/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7120e-04 - accuracy: 0.1289 - val_loss: 0.0126 - val_accuracy: 0.0126
# Epoch 254/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.3628e-04 - accuracy: 0.1289 - val_loss: 0.0145 - val_accuracy: 0.0126
# Epoch 255/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6069e-04 - accuracy: 0.1289 - val_loss: 0.0133 - val_accuracy: 0.0126
# Epoch 256/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9666e-04 - accuracy: 0.1289 - val_loss: 0.0099 - val_accuracy: 0.0126
# Epoch 257/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7922e-04 - accuracy: 0.1289 - val_loss: 0.0111 - val_accuracy: 0.0126
# Epoch 258/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5655e-04 - accuracy: 0.1289 - val_loss: 0.0098 - val_accuracy: 0.0126
# Epoch 259/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8017e-04 - accuracy: 0.1289 - val_loss: 0.0094 - val_accuracy: 0.0126
# Epoch 260/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6401e-04 - accuracy: 0.1289 - val_loss: 0.0130 - val_accuracy: 0.0126
# Epoch 261/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5756e-04 - accuracy: 0.1289 - val_loss: 0.0114 - val_accuracy: 0.0126
# Epoch 262/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5085e-04 - accuracy: 0.1289 - val_loss: 0.0081 - val_accuracy: 0.0126
# Epoch 263/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7841e-04 - accuracy: 0.1289 - val_loss: 0.0100 - val_accuracy: 0.0126
# Epoch 264/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6939e-04 - accuracy: 0.1289 - val_loss: 0.0131 - val_accuracy: 0.0126
# Epoch 265/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8006e-04 - accuracy: 0.1289 - val_loss: 0.0099 - val_accuracy: 0.0126
# Epoch 266/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5772e-04 - accuracy: 0.1289 - val_loss: 0.0159 - val_accuracy: 0.0126
# Epoch 267/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1017e-04 - accuracy: 0.1289 - val_loss: 0.0110 - val_accuracy: 0.0126
# Epoch 268/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4561e-04 - accuracy: 0.1289 - val_loss: 0.0127 - val_accuracy: 0.0126
# Epoch 269/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6271e-04 - accuracy: 0.1289 - val_loss: 0.0110 - val_accuracy: 0.0126
# Epoch 270/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7356e-04 - accuracy: 0.1289 - val_loss: 0.0122 - val_accuracy: 0.0126
# Epoch 271/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5559e-04 - accuracy: 0.1289 - val_loss: 0.0086 - val_accuracy: 0.0126
# Epoch 272/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4317e-04 - accuracy: 0.1289 - val_loss: 0.0075 - val_accuracy: 0.0126
# Epoch 273/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6392e-04 - accuracy: 0.1289 - val_loss: 0.0092 - val_accuracy: 0.0126
# Epoch 274/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7587e-04 - accuracy: 0.1289 - val_loss: 0.0061 - val_accuracy: 0.0126
# Epoch 275/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5131e-04 - accuracy: 0.1289 - val_loss: 0.0090 - val_accuracy: 0.0126
# Epoch 276/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6878e-04 - accuracy: 0.1289 - val_loss: 0.0095 - val_accuracy: 0.0126
# Epoch 277/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4526e-04 - accuracy: 0.1289 - val_loss: 0.0073 - val_accuracy: 0.0126
# Epoch 278/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6083e-04 - accuracy: 0.1289 - val_loss: 0.0122 - val_accuracy: 0.0126
# Epoch 279/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6576e-04 - accuracy: 0.1289 - val_loss: 0.0085 - val_accuracy: 0.0126
# Epoch 280/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6848e-04 - accuracy: 0.1289 - val_loss: 0.0074 - val_accuracy: 0.0126
# Epoch 281/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6518e-04 - accuracy: 0.1289 - val_loss: 0.0107 - val_accuracy: 0.0126
# Epoch 282/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.3045e-04 - accuracy: 0.1289 - val_loss: 0.0064 - val_accuracy: 0.0126
# Epoch 283/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5966e-04 - accuracy: 0.1289 - val_loss: 0.0083 - val_accuracy: 0.0126
# Epoch 284/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5887e-04 - accuracy: 0.1289 - val_loss: 0.0103 - val_accuracy: 0.0126
# Epoch 285/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5751e-04 - accuracy: 0.1289 - val_loss: 0.0068 - val_accuracy: 0.0126
# Epoch 286/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7437e-04 - accuracy: 0.1289 - val_loss: 0.0118 - val_accuracy: 0.0126
# Epoch 287/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4729e-04 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0126
# Epoch 288/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.2161e-04 - accuracy: 0.1289 - val_loss: 0.0049 - val_accuracy: 0.0126
# Epoch 289/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5158e-04 - accuracy: 0.1289 - val_loss: 0.0082 - val_accuracy: 0.0126
# Epoch 290/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6427e-04 - accuracy: 0.1289 - val_loss: 0.0081 - val_accuracy: 0.0126
# Epoch 291/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7497e-04 - accuracy: 0.1289 - val_loss: 0.0130 - val_accuracy: 0.0126
# Epoch 292/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5299e-04 - accuracy: 0.1289 - val_loss: 0.0072 - val_accuracy: 0.0126
# Epoch 293/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4487e-04 - accuracy: 0.1289 - val_loss: 0.0101 - val_accuracy: 0.0126
# Epoch 294/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4308e-04 - accuracy: 0.1289 - val_loss: 0.0047 - val_accuracy: 0.0126
# Epoch 295/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8471e-04 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0126
# Epoch 296/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5520e-04 - accuracy: 0.1289 - val_loss: 0.0091 - val_accuracy: 0.0126
# Epoch 297/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7953e-04 - accuracy: 0.1289 - val_loss: 0.0061 - val_accuracy: 0.0126
# Epoch 298/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4451e-04 - accuracy: 0.1289 - val_loss: 0.0055 - val_accuracy: 0.0126
# Epoch 299/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4773e-04 - accuracy: 0.1289 - val_loss: 0.0079 - val_accuracy: 0.0126
# Epoch 300/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.4150e-04 - accuracy: 0.1289 - val_loss: 0.0093 - val_accuracy: 0.0126
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: stacked bilstm/assets
# INFO:tensorflow:Assets written to: stacked bilstm/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe514bcd950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe514b53590> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe514b7b510> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe514b05390> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe514b0e390> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe514b1a110> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
losses_lstm = model.history.history['loss']
fig = plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(range(len(losses_lstm)),losses_lstm)
plt.grid()
fig.savefig('losses lstm.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
model.summary()
model.save('LSTM.h5')
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 2, 400)           323200
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 2, 400)           961600
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 40)               67360
#  nal)
#
#  dense (Dense)               (None, 1)                 41
#
# =================================================================
# Total params: 1,352,201
# Trainable params: 1,352,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions
print(f'trainPredict {trainPredict.shape}')
print(f'trainY {trainY.shape}')
print(f'testPredict {testPredict.shape}')
print(f'testY {testY.shape}')
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# trainPredict (795, 1)
# trainY (795,)
# testPredict (39, 1)
# testY (39,)

# %%
#Mean Squared Error
trainScore_MSE = mean_squared_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore_MSE))
testScore_MSE = mean_squared_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MSE' % (testScore_MSE))
# calculate root mean squared error
trainScore_RMSE = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore_RMSE))
testScore_RMSE = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore_RMSE))
#  Mean Absolute Error
trainScore_MAE = mean_absolute_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAE' % (trainScore_MAE))
testScore_MAE = mean_absolute_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAE' % (testScore_MAE))
#  Mean Absolute Percentage Error
trainScore_MAPE = mean_absolute_percentage_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAPE' % (trainScore_MAPE))
testScore_MAPE = mean_absolute_percentage_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAPE' % (testScore_MAPE))

#  Coefficient of Determination-R2 score
trainScore_r2 = r2_score(trainY[0], trainPredict[:,0])
print('Train Score: %.2f r2' % (trainScore_r2))
testScore_r2= r2_score(testY[0], testPredict[:,0])
print('Test Score: %.2f r2' % (testScore_r2))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# Out:
# Train Score: 3971.70 MSE
# Test Score: 1052.44 MSE
# Train Score: 63.02 RMSE
# Test Score: 32.44 RMSE
# Train Score: 39.61 MAE
# Test Score: 26.46 MAE
# Train Score: 2372751011693718.50 MAPE
# Test Score: 0.08 MAPE
# Train Score: 0.97 r2
# Test Score: 0.91 r2

# %%
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
fig = plt.figure(figsize=(12,4))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title(plot_title) 
plt.legend([Implementation, 'training','testing'], loc='upper left')
plt.xlabel(f'Time in {Time}')
plt.ylabel(Implementation)
plt.grid()
plt.show()
fig.savefig('final.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')

# %%
# predictions = model.predict() #this creates states
future_x = []
future_y = []
currentStep = dataset[-look_back:] #last step from the previous prediction
# model.reset_states()
for i in range(Forecasting_days):
    predicted = model.predict(currentStep.reshape(1,look_back,1)) #get the next step
    future_x.append(currentStep) #store the future steps \
    future_y.append(predicted)
    future_y[i] = np.reshape(scaler.inverse_transform(future_y[i]), 1)
    currentStep = np.concatenate((currentStep[1:], predicted), axis=0).astype(np.float32)
future_predictions_x = pd.DataFrame(np.array(future_x).reshape(Forecasting_days,look_back))
future_predictions_y = pd.DataFrame(future_y,columns=['Future'])
# print(future_predictions_x)
print(future_predictions_y)
# Out:
#        Future
# 0  184.268478
# 1  159.857788
# 2  141.158035
# 3  124.530121
# 4  114.739586
# 5  109.451073
# 6  107.018501
# 7  106.091064
# 8  105.759148
# 9  105.641022

# %%
file1 = open('Accuracy.txt', 'w')
file1.write(f'Train Score r2 %.2f : {trainScore_r2}\n Test Score r2 %.2f r2: {testScore_r2}\n Train Score MSE: {trainScore_MSE}\n Test Score MSE: {testScore_MSE}\n Train Score RMSE: {trainScore_RMSE}\n test Score RMSE: {testScore_RMSE}\n Train Score MAE: {trainScore_MAE}\n Test Score MAE: {testScore_MAE}\n Train Score MAPE: {trainScore_MAPE}\n Test Score MAPE: {testScore_MAPE}')
file1.close()

# %%
file2 = open('Prediction.txt', 'w')
file2.write(f'Prediction:\n {future_predictions_y}')
file2.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <a href="https://colab.research.google.com/github/abotalebmostafa11/DL-System/blob/main/GRU_deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25a00f3c-45d8-491b-99dd-6bae7f38082d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25a00f3c-45d8-491b-99dd-6bae7f38082d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Deaths.csv to Deaths.csv

# %%
# LSTM for Forecasting Covid 19 problem In Russian Fderation
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.layers import Dense,RepeatVector,LSTM,Dropout,GRU,Dense,SimpleRNN,Embedding 
from keras.callbacks import ModelCheckpoint, TensorBoard, Callback, EarlyStopping
from tensorflow.keras.layers import Flatten, Conv1D, MaxPooling1D
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Bidirectional, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, TimeDistributed
from keras.utils.vis_utils import plot_model
from keras.models import Model, load_model
from keras.layers import Dense, Softmax
from sklearn.metrics import r2_score
from keras.models import Sequential
import matplotlib.pyplot as plt
from pandas import read_csv
from numpy import array
import pandas as pd
import numpy as np
import numpy
import math

# %%
Data_Name="Deaths.csv"
Use_Percent = True
if Use_Percent:
    train_Percent = 0.95
else:
    Testing_Rows = 0
Forecasting_days = 10 # how many days that you want to forecast?
create_new_model = True
Time="days"
Implementation="Covid 19 daily deaths Cases in Russia"
plot_title="Modelling and forecasting deaths cases in Russia by using GRU Model "
Model_Name="gru"

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv(Data_Name, usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
if Use_Percent:
    train_size = int(len(dataset) * (train_Percent))
    test_size = len(dataset) - train_size
    pass
else:
    train_size = len(dataset) - Testing_Rows
    test_size = Testing_Rows
    pass

#train_size = int(len(dataset) * train_Percent)
#test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back=int(input('LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:'))
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
#trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
#testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = numpy.reshape(testX, (testX.shape[0], look_back, 1))
trainY = trainY.T
testY = testY.T
print(f'trainX = {trainX.shape}')
print(f'trainY = {trainY.shape}')
print(f'testX = {testX.shape}')
print(f'testY = {testY.shape}')
# Out:
# LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:2
# trainX = (795, 2, 1)
# trainY = (795,)
# testX = (39, 2, 1)
# testY = (39,)

# %%
# %%
if create_new_model:
    model = Sequential()
    n_input = 12
    n_features= 1
    generator = TimeseriesGenerator(dataset, dataset, length=n_input, batch_size=n_features)
    early_stop = EarlyStopping(monitor = "loss", mode = "min", patience = 7)
    #for layer in Model_Name:
    if Model_Name.lower() == "bilstm":
        # create and fit the BILSTM for Regression network (bilstm)
        print('Machine learning software = => create and fit the BILSTM for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN,activation=activation, input_shape=(look_back,1))))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked bilstm":
        # create and fit the BILSTM stack network (stacked bilstm)
        print('Machine learning software = => create and fit the stacked bilstm for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back,1))))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1))))
        model.add(Bidirectional(LSTM(20)))
        model.add(Dense(1))
    if  Model_Name.lower() == "convlstms":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstms)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(Conv1D(filters=128, kernel_size=2, activation=activation))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(RepeatVector(30))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Bidirectional(LSTM(128, activation=activation)))
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "conv":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "lstm":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked lstm":
        print('Machine learning software = => create and fit the stacked lstm for Regression network...')
        # create and fit the Stacked LSTM for Regression network (stacked lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(20))
        model.add(Dense(1))     
    if  Model_Name.lower() == "gru":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(GRU(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    model.compile(loss=inputloss_function, optimizer=inputoptimizer_name,metrics=['accuracy'])
    history =model.fit(trainX, trainY, epochs=N_epochs, batch_size=1, verbose=True,validation_split=0.2, shuffle=True)
    print(history.history.keys())
    #  "Accuracy"
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('Accuracy.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    # "Loss" # plot train and validation loss
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model train vs validation loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('plot train and validation loss.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    model.save(Model_Name)
else:
    model = load_model(Model_Name)
    model.summary()
# Out:
# Machine learning software = => create and fit the lstm for Regression network...
# Enter the number of epochs:300
# Enter the Loss Function:MeanSquaredError
# Enter the Optimizer Name:adam
# Enter the activation function name:relu
# Enter the number of neurans:200
# Epoch 1/300
# 636/636 [==============================] - 5s 6ms/step - loss: 0.0055 - accuracy: 0.1289 - val_loss: 0.0052 - val_accuracy: 0.0126
# Epoch 2/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 3/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0045 - val_accuracy: 0.0126
# Epoch 4/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 5/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 6/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 7/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 9.0011e-04 - val_accuracy: 0.0126
# Epoch 8/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 9/300
# 636/636 [==============================] - 3s 5ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 10/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 6.0383e-04 - val_accuracy: 0.0126
# Epoch 11/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 12/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 8.5112e-04 - val_accuracy: 0.0126
# Epoch 13/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 9.3343e-04 - val_accuracy: 0.0126
# Epoch 14/300
# 636/636 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 15/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.3634e-04 - val_accuracy: 0.0126
# Epoch 16/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 6.2015e-04 - val_accuracy: 0.0126
# Epoch 17/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 18/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.5683e-04 - val_accuracy: 0.0126
# Epoch 19/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 20/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.0226e-04 - val_accuracy: 0.0126
# Epoch 21/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 6.1173e-04 - val_accuracy: 0.0126
# Epoch 22/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 8.3950e-04 - val_accuracy: 0.0126
# Epoch 23/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 3.9971e-04 - val_accuracy: 0.0126
# Epoch 24/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 7.1943e-04 - val_accuracy: 0.0126
# Epoch 25/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.0867e-04 - val_accuracy: 0.0126
# Epoch 26/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.2771e-04 - val_accuracy: 0.0126
# Epoch 27/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 28/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.4036e-04 - val_accuracy: 0.0126
# Epoch 29/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.7884e-04 - val_accuracy: 0.0126
# Epoch 30/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.1258e-04 - val_accuracy: 0.0126
# Epoch 31/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.3414e-04 - val_accuracy: 0.0126
# Epoch 32/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.8223e-04 - val_accuracy: 0.0126
# Epoch 33/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 34/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.3512e-04 - val_accuracy: 0.0126
# Epoch 35/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 36/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 3.8153e-04 - val_accuracy: 0.0126
# Epoch 37/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 9.8734e-04 - val_accuracy: 0.0126
# Epoch 38/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.1497e-04 - val_accuracy: 0.0126
# Epoch 39/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.4420e-04 - val_accuracy: 0.0126
# Epoch 40/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 41/300
# 636/636 [==============================] - 2s 3ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 42/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 43/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9640e-04 - accuracy: 0.1289 - val_loss: 3.9166e-04 - val_accuracy: 0.0126
# Epoch 44/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.3673e-04 - val_accuracy: 0.0126
# Epoch 45/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.8302e-04 - val_accuracy: 0.0126
# Epoch 46/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.6796e-04 - val_accuracy: 0.0126
# Epoch 47/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9712e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 48/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 9.0010e-04 - val_accuracy: 0.0126
# Epoch 49/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9924e-04 - accuracy: 0.1289 - val_loss: 5.7210e-04 - val_accuracy: 0.0126
# Epoch 50/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 51/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9316e-04 - accuracy: 0.1289 - val_loss: 3.7002e-04 - val_accuracy: 0.0126
# Epoch 52/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 53/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.3337e-04 - val_accuracy: 0.0126
# Epoch 54/300
# 636/636 [==============================] - 3s 5ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.5343e-04 - val_accuracy: 0.0126
# Epoch 55/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.9836e-04 - val_accuracy: 0.0126
# Epoch 56/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.1374e-04 - val_accuracy: 0.0126
# Epoch 57/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8734e-04 - accuracy: 0.1289 - val_loss: 8.1202e-04 - val_accuracy: 0.0126
# Epoch 58/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.0377e-04 - val_accuracy: 0.0126
# Epoch 59/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.7279e-04 - val_accuracy: 0.0126
# Epoch 60/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8946e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 61/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 6.3037e-04 - val_accuracy: 0.0126
# Epoch 62/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8134e-04 - accuracy: 0.1289 - val_loss: 5.6608e-04 - val_accuracy: 0.0126
# Epoch 63/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.7949e-04 - val_accuracy: 0.0126
# Epoch 64/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7338e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 65/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.9042e-04 - val_accuracy: 0.0126
# Epoch 66/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9182e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 67/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 68/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8857e-04 - accuracy: 0.1289 - val_loss: 6.4260e-04 - val_accuracy: 0.0126
# Epoch 69/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 70/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5224e-04 - accuracy: 0.1289 - val_loss: 8.4091e-04 - val_accuracy: 0.0126
# Epoch 71/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.6307e-04 - val_accuracy: 0.0126
# Epoch 72/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9208e-04 - accuracy: 0.1289 - val_loss: 6.1101e-04 - val_accuracy: 0.0126
# Epoch 73/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8023e-04 - accuracy: 0.1289 - val_loss: 3.8108e-04 - val_accuracy: 0.0126
# Epoch 74/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 7.7003e-04 - val_accuracy: 0.0126
# Epoch 75/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8849e-04 - accuracy: 0.1289 - val_loss: 7.3416e-04 - val_accuracy: 0.0126
# Epoch 76/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.8020e-04 - accuracy: 0.1289 - val_loss: 7.7158e-04 - val_accuracy: 0.0126
# Epoch 77/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6812e-04 - accuracy: 0.1289 - val_loss: 3.8399e-04 - val_accuracy: 0.0126
# Epoch 78/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.2654e-04 - val_accuracy: 0.0126
# Epoch 79/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.8508e-04 - val_accuracy: 0.0126
# Epoch 80/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7754e-04 - accuracy: 0.1289 - val_loss: 6.3458e-04 - val_accuracy: 0.0126
# Epoch 81/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6373e-04 - accuracy: 0.1289 - val_loss: 5.1007e-04 - val_accuracy: 0.0126
# Epoch 82/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6727e-04 - accuracy: 0.1289 - val_loss: 5.7848e-04 - val_accuracy: 0.0126
# Epoch 83/300
# 636/636 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 84/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.9011e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 85/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.7859e-04 - accuracy: 0.1289 - val_loss: 6.9513e-04 - val_accuracy: 0.0126
# Epoch 86/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6879e-04 - accuracy: 0.1289 - val_loss: 4.0734e-04 - val_accuracy: 0.0126
# Epoch 87/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 88/300
# 636/636 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 6.1575e-04 - val_accuracy: 0.0126
# Epoch 89/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6103e-04 - accuracy: 0.1289 - val_loss: 8.0852e-04 - val_accuracy: 0.0126
# Epoch 90/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7790e-04 - accuracy: 0.1289 - val_loss: 5.8920e-04 - val_accuracy: 0.0126
# Epoch 91/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7848e-04 - accuracy: 0.1289 - val_loss: 5.7069e-04 - val_accuracy: 0.0126
# Epoch 92/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5986e-04 - accuracy: 0.1289 - val_loss: 4.7179e-04 - val_accuracy: 0.0126
# Epoch 93/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6425e-04 - accuracy: 0.1289 - val_loss: 4.1402e-04 - val_accuracy: 0.0126
# Epoch 94/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6704e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 95/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.9534e-04 - accuracy: 0.1289 - val_loss: 5.4890e-04 - val_accuracy: 0.0126
# Epoch 96/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5838e-04 - accuracy: 0.1289 - val_loss: 5.7819e-04 - val_accuracy: 0.0126
# Epoch 97/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7746e-04 - accuracy: 0.1289 - val_loss: 6.3587e-04 - val_accuracy: 0.0126
# Epoch 98/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6426e-04 - accuracy: 0.1289 - val_loss: 9.1971e-04 - val_accuracy: 0.0126
# Epoch 99/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6765e-04 - accuracy: 0.1289 - val_loss: 9.4844e-04 - val_accuracy: 0.0126
# Epoch 100/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5494e-04 - accuracy: 0.1289 - val_loss: 6.1018e-04 - val_accuracy: 0.0126
# Epoch 101/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6024e-04 - accuracy: 0.1289 - val_loss: 5.3971e-04 - val_accuracy: 0.0126
# Epoch 102/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4956e-04 - accuracy: 0.1289 - val_loss: 5.4100e-04 - val_accuracy: 0.0126
# Epoch 103/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7078e-04 - accuracy: 0.1289 - val_loss: 6.1050e-04 - val_accuracy: 0.0126
# Epoch 104/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7013e-04 - accuracy: 0.1289 - val_loss: 5.8240e-04 - val_accuracy: 0.0126
# Epoch 105/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5214e-04 - accuracy: 0.1289 - val_loss: 4.5539e-04 - val_accuracy: 0.0126
# Epoch 106/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4553e-04 - accuracy: 0.1289 - val_loss: 5.2969e-04 - val_accuracy: 0.0126
# Epoch 107/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6980e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 108/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7417e-04 - accuracy: 0.1289 - val_loss: 7.2961e-04 - val_accuracy: 0.0126
# Epoch 109/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4653e-04 - accuracy: 0.1289 - val_loss: 4.1221e-04 - val_accuracy: 0.0126
# Epoch 110/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6958e-04 - accuracy: 0.1289 - val_loss: 4.3005e-04 - val_accuracy: 0.0126
# Epoch 111/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6916e-04 - accuracy: 0.1289 - val_loss: 3.9748e-04 - val_accuracy: 0.0126
# Epoch 112/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3892e-04 - accuracy: 0.1289 - val_loss: 6.2902e-04 - val_accuracy: 0.0126
# Epoch 113/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6534e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 114/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4331e-04 - accuracy: 0.1289 - val_loss: 3.8885e-04 - val_accuracy: 0.0126
# Epoch 115/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4450e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 116/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4286e-04 - accuracy: 0.1289 - val_loss: 4.0190e-04 - val_accuracy: 0.0126
# Epoch 117/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5270e-04 - accuracy: 0.1289 - val_loss: 6.6095e-04 - val_accuracy: 0.0126
# Epoch 118/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3883e-04 - accuracy: 0.1289 - val_loss: 3.9728e-04 - val_accuracy: 0.0126
# Epoch 119/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5302e-04 - accuracy: 0.1289 - val_loss: 6.7152e-04 - val_accuracy: 0.0126
# Epoch 120/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5804e-04 - accuracy: 0.1289 - val_loss: 5.8012e-04 - val_accuracy: 0.0126
# Epoch 121/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7971e-04 - accuracy: 0.1289 - val_loss: 4.4792e-04 - val_accuracy: 0.0126
# Epoch 122/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4623e-04 - accuracy: 0.1289 - val_loss: 4.6114e-04 - val_accuracy: 0.0126
# Epoch 123/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4483e-04 - accuracy: 0.1289 - val_loss: 7.0371e-04 - val_accuracy: 0.0126
# Epoch 124/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5260e-04 - accuracy: 0.1289 - val_loss: 8.3000e-04 - val_accuracy: 0.0126
# Epoch 125/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.6381e-04 - accuracy: 0.1289 - val_loss: 3.8160e-04 - val_accuracy: 0.0126
# Epoch 126/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4465e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 127/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5513e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 128/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3877e-04 - accuracy: 0.1289 - val_loss: 5.9526e-04 - val_accuracy: 0.0126
# Epoch 129/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3986e-04 - accuracy: 0.1289 - val_loss: 5.9685e-04 - val_accuracy: 0.0126
# Epoch 130/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5429e-04 - accuracy: 0.1289 - val_loss: 8.3631e-04 - val_accuracy: 0.0126
# Epoch 131/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4243e-04 - accuracy: 0.1289 - val_loss: 5.7578e-04 - val_accuracy: 0.0126
# Epoch 132/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3786e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 133/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2679e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 134/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4844e-04 - accuracy: 0.1289 - val_loss: 5.7940e-04 - val_accuracy: 0.0126
# Epoch 135/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4954e-04 - accuracy: 0.1289 - val_loss: 4.2453e-04 - val_accuracy: 0.0126
# Epoch 136/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3049e-04 - accuracy: 0.1289 - val_loss: 5.3972e-04 - val_accuracy: 0.0126
# Epoch 137/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5247e-04 - accuracy: 0.1289 - val_loss: 4.6671e-04 - val_accuracy: 0.0126
# Epoch 138/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.6113e-04 - accuracy: 0.1289 - val_loss: 4.1533e-04 - val_accuracy: 0.0126
# Epoch 139/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5000e-04 - accuracy: 0.1289 - val_loss: 7.3021e-04 - val_accuracy: 0.0126
# Epoch 140/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5475e-04 - accuracy: 0.1289 - val_loss: 7.7507e-04 - val_accuracy: 0.0126
# Epoch 141/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4242e-04 - accuracy: 0.1289 - val_loss: 4.3537e-04 - val_accuracy: 0.0126
# Epoch 142/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5482e-04 - accuracy: 0.1289 - val_loss: 7.3714e-04 - val_accuracy: 0.0126
# Epoch 143/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.4335e-04 - accuracy: 0.1289 - val_loss: 4.7258e-04 - val_accuracy: 0.0126
# Epoch 144/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2797e-04 - accuracy: 0.1289 - val_loss: 7.9522e-04 - val_accuracy: 0.0126
# Epoch 145/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4146e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 146/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5927e-04 - accuracy: 0.1289 - val_loss: 4.7821e-04 - val_accuracy: 0.0126
# Epoch 147/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1953e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 148/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4485e-04 - accuracy: 0.1289 - val_loss: 3.9237e-04 - val_accuracy: 0.0126
# Epoch 149/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3855e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 150/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.7638e-04 - accuracy: 0.1289 - val_loss: 4.6371e-04 - val_accuracy: 0.0126
# Epoch 151/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1554e-04 - accuracy: 0.1289 - val_loss: 3.9665e-04 - val_accuracy: 0.0126
# Epoch 152/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3972e-04 - accuracy: 0.1289 - val_loss: 4.2648e-04 - val_accuracy: 0.0126
# Epoch 153/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1987e-04 - accuracy: 0.1289 - val_loss: 6.7197e-04 - val_accuracy: 0.0126
# Epoch 154/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3892e-04 - accuracy: 0.1289 - val_loss: 6.1282e-04 - val_accuracy: 0.0126
# Epoch 155/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2155e-04 - accuracy: 0.1289 - val_loss: 5.8130e-04 - val_accuracy: 0.0126
# Epoch 156/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3456e-04 - accuracy: 0.1289 - val_loss: 8.5654e-04 - val_accuracy: 0.0126
# Epoch 157/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2006e-04 - accuracy: 0.1289 - val_loss: 8.0168e-04 - val_accuracy: 0.0126
# Epoch 158/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3824e-04 - accuracy: 0.1289 - val_loss: 8.2791e-04 - val_accuracy: 0.0126
# Epoch 159/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4785e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 160/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4056e-04 - accuracy: 0.1289 - val_loss: 8.3529e-04 - val_accuracy: 0.0126
# Epoch 161/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2225e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 162/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5261e-04 - accuracy: 0.1289 - val_loss: 4.5576e-04 - val_accuracy: 0.0126
# Epoch 163/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2103e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 164/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1798e-04 - accuracy: 0.1289 - val_loss: 8.6256e-04 - val_accuracy: 0.0126
# Epoch 165/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4686e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 166/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3157e-04 - accuracy: 0.1289 - val_loss: 5.3431e-04 - val_accuracy: 0.0126
# Epoch 167/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2131e-04 - accuracy: 0.1289 - val_loss: 8.4784e-04 - val_accuracy: 0.0126
# Epoch 168/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3252e-04 - accuracy: 0.1289 - val_loss: 6.9141e-04 - val_accuracy: 0.0126
# Epoch 169/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1482e-04 - accuracy: 0.1289 - val_loss: 5.5814e-04 - val_accuracy: 0.0126
# Epoch 170/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2158e-04 - accuracy: 0.1289 - val_loss: 7.5990e-04 - val_accuracy: 0.0126
# Epoch 171/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0509e-04 - accuracy: 0.1289 - val_loss: 4.6853e-04 - val_accuracy: 0.0126
# Epoch 172/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2994e-04 - accuracy: 0.1289 - val_loss: 4.3655e-04 - val_accuracy: 0.0126
# Epoch 173/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2663e-04 - accuracy: 0.1289 - val_loss: 8.3604e-04 - val_accuracy: 0.0126
# Epoch 174/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1615e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 175/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1786e-04 - accuracy: 0.1289 - val_loss: 5.3625e-04 - val_accuracy: 0.0126
# Epoch 176/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3680e-04 - accuracy: 0.1289 - val_loss: 4.8546e-04 - val_accuracy: 0.0126
# Epoch 177/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4114e-04 - accuracy: 0.1289 - val_loss: 6.9703e-04 - val_accuracy: 0.0126
# Epoch 178/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2187e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 179/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3482e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 180/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3672e-04 - accuracy: 0.1289 - val_loss: 5.8163e-04 - val_accuracy: 0.0126
# Epoch 181/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.5474e-04 - accuracy: 0.1289 - val_loss: 4.5115e-04 - val_accuracy: 0.0126
# Epoch 182/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2938e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 183/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.5305e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 184/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1500e-04 - accuracy: 0.1289 - val_loss: 8.8660e-04 - val_accuracy: 0.0126
# Epoch 185/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1891e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 186/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4384e-04 - accuracy: 0.1289 - val_loss: 9.5384e-04 - val_accuracy: 0.0126
# Epoch 187/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0666e-04 - accuracy: 0.1289 - val_loss: 5.2393e-04 - val_accuracy: 0.0126
# Epoch 188/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0101e-04 - accuracy: 0.1289 - val_loss: 9.4780e-04 - val_accuracy: 0.0126
# Epoch 189/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0978e-04 - accuracy: 0.1289 - val_loss: 0.0026 - val_accuracy: 0.0126
# Epoch 190/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4677e-04 - accuracy: 0.1289 - val_loss: 0.0026 - val_accuracy: 0.0126
# Epoch 191/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3434e-04 - accuracy: 0.1289 - val_loss: 4.9799e-04 - val_accuracy: 0.0126
# Epoch 192/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1420e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 193/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3530e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 194/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1021e-04 - accuracy: 0.1289 - val_loss: 5.4427e-04 - val_accuracy: 0.0126
# Epoch 195/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4561e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 196/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3781e-04 - accuracy: 0.1289 - val_loss: 8.9165e-04 - val_accuracy: 0.0126
# Epoch 197/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1888e-04 - accuracy: 0.1289 - val_loss: 9.0283e-04 - val_accuracy: 0.0126
# Epoch 198/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2411e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 199/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0685e-04 - accuracy: 0.1289 - val_loss: 6.3163e-04 - val_accuracy: 0.0126
# Epoch 200/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1263e-04 - accuracy: 0.1289 - val_loss: 8.5296e-04 - val_accuracy: 0.0126
# Epoch 201/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.4593e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 202/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1681e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 203/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0076e-04 - accuracy: 0.1289 - val_loss: 6.1486e-04 - val_accuracy: 0.0126
# Epoch 204/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1629e-04 - accuracy: 0.1289 - val_loss: 6.0210e-04 - val_accuracy: 0.0126
# Epoch 205/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9242e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 206/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3226e-04 - accuracy: 0.1289 - val_loss: 5.9539e-04 - val_accuracy: 0.0126
# Epoch 207/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2323e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 208/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2133e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 209/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1274e-04 - accuracy: 0.1289 - val_loss: 6.9373e-04 - val_accuracy: 0.0126
# Epoch 210/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1105e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 211/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0682e-04 - accuracy: 0.1289 - val_loss: 7.7643e-04 - val_accuracy: 0.0126
# Epoch 212/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1310e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 213/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0767e-04 - accuracy: 0.1289 - val_loss: 5.8105e-04 - val_accuracy: 0.0126
# Epoch 214/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9933e-04 - accuracy: 0.1289 - val_loss: 6.4979e-04 - val_accuracy: 0.0126
# Epoch 215/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0092e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 216/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1398e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 217/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0266e-04 - accuracy: 0.1289 - val_loss: 9.2351e-04 - val_accuracy: 0.0126
# Epoch 218/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0899e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 219/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0067e-04 - accuracy: 0.1289 - val_loss: 5.1246e-04 - val_accuracy: 0.0126
# Epoch 220/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1345e-04 - accuracy: 0.1289 - val_loss: 8.5565e-04 - val_accuracy: 0.0126
# Epoch 221/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.1627e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 222/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0725e-04 - accuracy: 0.1289 - val_loss: 5.7454e-04 - val_accuracy: 0.0126
# Epoch 223/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0295e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 224/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1031e-04 - accuracy: 0.1289 - val_loss: 7.3860e-04 - val_accuracy: 0.0126
# Epoch 225/300
# 636/636 [==============================] - 2s 4ms/step - loss: 8.9581e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 226/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9728e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 227/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.3451e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 228/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1837e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 229/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1915e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 230/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0432e-04 - accuracy: 0.1289 - val_loss: 6.9280e-04 - val_accuracy: 0.0126
# Epoch 231/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9054e-04 - accuracy: 0.1289 - val_loss: 5.3723e-04 - val_accuracy: 0.0126
# Epoch 232/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2209e-04 - accuracy: 0.1289 - val_loss: 0.0023 - val_accuracy: 0.0126
# Epoch 233/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0416e-04 - accuracy: 0.1289 - val_loss: 6.0577e-04 - val_accuracy: 0.0126
# Epoch 234/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0995e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 235/300
# 636/636 [==============================] - 2s 4ms/step - loss: 8.7663e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 236/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2414e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 237/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1055e-04 - accuracy: 0.1289 - val_loss: 7.1620e-04 - val_accuracy: 0.0126
# Epoch 238/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9764e-04 - accuracy: 0.1289 - val_loss: 0.0029 - val_accuracy: 0.0126
# Epoch 239/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2821e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 240/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2831e-04 - accuracy: 0.1289 - val_loss: 8.9963e-04 - val_accuracy: 0.0126
# Epoch 241/300
# 636/636 [==============================] - 2s 4ms/step - loss: 8.9587e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 242/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0469e-04 - accuracy: 0.1289 - val_loss: 9.4598e-04 - val_accuracy: 0.0126
# Epoch 243/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8550e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 244/300
# 636/636 [==============================] - 2s 4ms/step - loss: 8.8445e-04 - accuracy: 0.1289 - val_loss: 7.1898e-04 - val_accuracy: 0.0126
# Epoch 245/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8500e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 246/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0909e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 247/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0378e-04 - accuracy: 0.1289 - val_loss: 8.6504e-04 - val_accuracy: 0.0126
# Epoch 248/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.0892e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 249/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9486e-04 - accuracy: 0.1289 - val_loss: 6.6820e-04 - val_accuracy: 0.0126
# Epoch 250/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0815e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 251/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2686e-04 - accuracy: 0.1289 - val_loss: 9.0523e-04 - val_accuracy: 0.0126
# Epoch 252/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8721e-04 - accuracy: 0.1289 - val_loss: 0.0041 - val_accuracy: 0.0126
# Epoch 253/300
# 636/636 [==============================] - 2s 4ms/step - loss: 9.2543e-04 - accuracy: 0.1289 - val_loss: 6.4108e-04 - val_accuracy: 0.0126
# Epoch 254/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9254e-04 - accuracy: 0.1289 - val_loss: 9.0645e-04 - val_accuracy: 0.0126
# Epoch 255/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0859e-04 - accuracy: 0.1289 - val_loss: 6.2453e-04 - val_accuracy: 0.0126
# Epoch 256/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9727e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 257/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8686e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 258/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8945e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 259/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0105e-04 - accuracy: 0.1289 - val_loss: 0.0039 - val_accuracy: 0.0126
# Epoch 260/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0024e-04 - accuracy: 0.1289 - val_loss: 6.8913e-04 - val_accuracy: 0.0126
# Epoch 261/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3177e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 262/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2091e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 263/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0244e-04 - accuracy: 0.1289 - val_loss: 0.0040 - val_accuracy: 0.0126
# Epoch 264/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2077e-04 - accuracy: 0.1289 - val_loss: 0.0033 - val_accuracy: 0.0126
# Epoch 265/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.3060e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 266/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9895e-04 - accuracy: 0.1289 - val_loss: 8.5259e-04 - val_accuracy: 0.0126
# Epoch 267/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0946e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 268/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9948e-04 - accuracy: 0.1289 - val_loss: 7.5783e-04 - val_accuracy: 0.0126
# Epoch 269/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0807e-04 - accuracy: 0.1289 - val_loss: 0.0044 - val_accuracy: 0.0126
# Epoch 270/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1185e-04 - accuracy: 0.1289 - val_loss: 0.0033 - val_accuracy: 0.0126
# Epoch 271/300
# 636/636 [==============================] - 3s 5ms/step - loss: 9.1174e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 272/300
# 636/636 [==============================] - 6s 9ms/step - loss: 8.9015e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 273/300
# 636/636 [==============================] - 5s 8ms/step - loss: 8.7292e-04 - accuracy: 0.1289 - val_loss: 7.9385e-04 - val_accuracy: 0.0126
# Epoch 274/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.7770e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 275/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9220e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 276/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2360e-04 - accuracy: 0.1289 - val_loss: 7.2821e-04 - val_accuracy: 0.0126
# Epoch 277/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9264e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 278/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2009e-04 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 279/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.7943e-04 - accuracy: 0.1289 - val_loss: 8.1682e-04 - val_accuracy: 0.0126
# Epoch 280/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8435e-04 - accuracy: 0.1289 - val_loss: 7.4552e-04 - val_accuracy: 0.0126
# Epoch 281/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0657e-04 - accuracy: 0.1289 - val_loss: 9.5883e-04 - val_accuracy: 0.0126
# Epoch 282/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9116e-04 - accuracy: 0.1289 - val_loss: 0.0024 - val_accuracy: 0.0126
# Epoch 283/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8851e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 284/300
# 636/636 [==============================] - 2s 4ms/step - loss: 8.9948e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 285/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8006e-04 - accuracy: 0.1289 - val_loss: 0.0043 - val_accuracy: 0.0126
# Epoch 286/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0517e-04 - accuracy: 0.1289 - val_loss: 9.8731e-04 - val_accuracy: 0.0126
# Epoch 287/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.7534e-04 - accuracy: 0.1289 - val_loss: 7.7704e-04 - val_accuracy: 0.0126
# Epoch 288/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.1361e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 289/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9179e-04 - accuracy: 0.1289 - val_loss: 8.3658e-04 - val_accuracy: 0.0126
# Epoch 290/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8752e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 291/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9192e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 292/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8549e-04 - accuracy: 0.1289 - val_loss: 0.0031 - val_accuracy: 0.0126
# Epoch 293/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9195e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 294/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.7065e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 295/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.7073e-04 - accuracy: 0.1289 - val_loss: 9.7802e-04 - val_accuracy: 0.0126
# Epoch 296/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.0376e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 297/300
# 636/636 [==============================] - 3s 4ms/step - loss: 9.2479e-04 - accuracy: 0.1289 - val_loss: 8.4002e-04 - val_accuracy: 0.0126
# Epoch 298/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.8206e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 299/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9452e-04 - accuracy: 0.1289 - val_loss: 0.0027 - val_accuracy: 0.0126
# Epoch 300/300
# 636/636 [==============================] - 3s 4ms/step - loss: 8.9109e-04 - accuracy: 0.1289 - val_loss: 9.6607e-04 - val_accuracy: 0.0126
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# INFO:tensorflow:Assets written to: gru/assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x7fc5ff648190> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
losses_lstm = model.history.history['loss']
fig = plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(range(len(losses_lstm)),losses_lstm)
plt.grid()
fig.savefig('losses lstm.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
model.summary()
model.save('LSTM.h5')
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 200)               121800
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 122,001
# Trainable params: 122,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions
print(f'trainPredict {trainPredict.shape}')
print(f'trainY {trainY.shape}')
print(f'testPredict {testPredict.shape}')
print(f'testY {testY.shape}')
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# trainPredict (795, 1)
# trainY (795,)
# testPredict (39, 1)
# testY (39,)

# %%
#Mean Squared Error
trainScore_MSE = mean_squared_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore_MSE))
testScore_MSE = mean_squared_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MSE' % (testScore_MSE))
# calculate root mean squared error
trainScore_RMSE = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore_RMSE))
testScore_RMSE = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore_RMSE))
#  Mean Absolute Error
trainScore_MAE = mean_absolute_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAE' % (trainScore_MAE))
testScore_MAE = mean_absolute_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAE' % (testScore_MAE))
#  Mean Absolute Percentage Error
trainScore_MAPE = mean_absolute_percentage_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAPE' % (trainScore_MAPE))
testScore_MAPE = mean_absolute_percentage_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAPE' % (testScore_MAPE))

#  Coefficient of Determination-R2 score
trainScore_r2 = r2_score(trainY[0], trainPredict[:,0])
print('Train Score: %.2f r2' % (trainScore_r2))
testScore_r2= r2_score(testY[0], testPredict[:,0])
print('Test Score: %.2f r2' % (testScore_r2))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# Out:
# Train Score: 1350.20 MSE
# Test Score: 1175.82 MSE
# Train Score: 36.75 RMSE
# Test Score: 34.29 RMSE
# Train Score: 26.36 MAE
# Test Score: 30.24 MAE
# Train Score: 2467682279456562.00 MAPE
# Test Score: 0.09 MAPE
# Train Score: 0.99 r2
# Test Score: 0.90 r2

# %%
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
fig = plt.figure(figsize=(12,4))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title(plot_title) 
plt.legend([Implementation, 'training','testing'], loc='upper left')
plt.xlabel(f'Time in {Time}')
plt.ylabel(Implementation)
plt.grid()
plt.show()
fig.savefig('final.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')

# %%
# predictions = model.predict() #this creates states
future_x = []
future_y = []
currentStep = dataset[-look_back:] #last step from the previous prediction
# model.reset_states()
for i in range(Forecasting_days):
    predicted = model.predict(currentStep.reshape(1,look_back,1)) #get the next step
    future_x.append(currentStep) #store the future steps \
    future_y.append(predicted)
    future_y[i] = np.reshape(scaler.inverse_transform(future_y[i]), 1)
    currentStep = np.concatenate((currentStep[1:], predicted), axis=0).astype(np.float32)
future_predictions_x = pd.DataFrame(np.array(future_x).reshape(Forecasting_days,look_back))
future_predictions_y = pd.DataFrame(future_y,columns=['Future'])
# print(future_predictions_x)
print(future_predictions_y)
# Out:
#        Future
# 0  211.830231
# 1  212.078262
# 2  219.150665
# 3  224.964905
# 4  233.035446
# 5  242.417313
# 6  254.073593
# 7  268.405945
# 8  286.325317
# 9  307.686707

# %%
file1 = open('Accuracy.txt', 'w')
file1.write(f'Train Score r2 %.2f : {trainScore_r2}\n Test Score r2 %.2f r2: {testScore_r2}\n Train Score MSE: {trainScore_MSE}\n Test Score MSE: {testScore_MSE}\n Train Score RMSE: {trainScore_RMSE}\n test Score RMSE: {testScore_RMSE}\n Train Score MAE: {trainScore_MAE}\n Test Score MAE: {testScore_MAE}\n Train Score MAPE: {trainScore_MAPE}\n Test Score MAPE: {testScore_MAPE}')
file1.close()

# %%
file2 = open('Prediction.txt', 'w')
file2.write(f'Prediction:\n {future_predictions_y}')
file2.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

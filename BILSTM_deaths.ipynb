# %% [markdown]
# <a href="https://colab.research.google.com/github/abotalebmostafa11/DL-System/blob/main/BILSTM_deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-59bc63b5-18a2-4239-8546-cad8c867180e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59bc63b5-18a2-4239-8546-cad8c867180e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Deaths.csv to Deaths.csv

# %%
# LSTM for Forecasting Covid 19 problem In Russian Fderation
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.layers import Dense,RepeatVector,LSTM,Dropout,GRU,Dense,SimpleRNN,Embedding 
from keras.callbacks import ModelCheckpoint, TensorBoard, Callback, EarlyStopping
from tensorflow.keras.layers import Flatten, Conv1D, MaxPooling1D
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import Bidirectional, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, TimeDistributed
from keras.utils.vis_utils import plot_model
from keras.models import Model, load_model
from keras.layers import Dense, Softmax
from sklearn.metrics import r2_score
from keras.models import Sequential
import matplotlib.pyplot as plt
from pandas import read_csv
from numpy import array
import pandas as pd
import numpy as np
import numpy
import math

# %%
Data_Name="Deaths.csv"
Use_Percent = True
if Use_Percent:
    train_Percent = 0.95
else:
    Testing_Rows = 0
Forecasting_days = 10 # how many days that you want to forecast?
create_new_model = True
Time="days"
Implementation="Covid 19 daily deaths Cases in Russia"
plot_title="Modelling and forecasting deaths cases in Russia by using bilstm Model "
Model_Name="bilstm"

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset
dataframe = read_csv(Data_Name, usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
if Use_Percent:
    train_size = int(len(dataset) * (train_Percent))
    test_size = len(dataset) - train_size
    pass
else:
    train_size = len(dataset) - Testing_Rows
    test_size = Testing_Rows
    pass

#train_size = int(len(dataset) * train_Percent)
#test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back=int(input('LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:'))
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
#trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
#testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, 1))
testX = numpy.reshape(testX, (testX.shape[0], look_back, 1))
trainY = trainY.T
testY = testY.T
print(f'trainX = {trainX.shape}')
print(f'trainY = {trainY.shape}')
print(f'testX = {testX.shape}')
print(f'testY = {testY.shape}')
# Out:
# LSTM for Regression Using the Window Method (increasing the look_back argument from 1 to 3)[№ look back]:2
# trainX = (795, 2, 1)
# trainY = (795,)
# testX = (39, 2, 1)
# testY = (39,)

# %%
# %%
if create_new_model:
    model = Sequential()
    n_input = 12
    n_features= 1
    generator = TimeseriesGenerator(dataset, dataset, length=n_input, batch_size=n_features)
    early_stop = EarlyStopping(monitor = "loss", mode = "min", patience = 7)
    #for layer in Model_Name:
    if Model_Name.lower() == "bilstm":
        # create and fit the BILSTM for Regression network (bilstm)
        print('Machine learning software = => create and fit the BILSTM for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN,activation=activation, input_shape=(look_back,1))))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked bilstm":
        # create and fit the BILSTM stack network (stacked bilstm)
        print('Machine learning software = => create and fit the stacked bilstm for Regression network...')
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back,1))))
        model.add(Bidirectional(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1))))
        model.add(Bidirectional(LSTM(20)))
        model.add(Dense(1))
    if  Model_Name.lower() == "convlstms":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstms)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(Conv1D(filters=128, kernel_size=2, activation=activation))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(RepeatVector(30))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Dropout(0.2))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(LSTM(units=100, return_sequences=True, activation=activation))
        model.add(Bidirectional(LSTM(128, activation=activation)))
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "conv":
        print('Machine learning software = => create and fit the convlstms for Regression network...')
        look_back=30
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        # reshape input to be [samples, time steps, features]
        trainX = trainX.reshape(trainX.shape[0], trainX.shape[1],1)
        testX = testX.reshape(testX.shape[0], testX.shape[1],1)
        trainY = trainY.T
        testY = testY.T
        print(f'trainX = {trainX.shape}')
        print(f'trainY = {trainY.shape}')
        print(f'testX = {testX.shape}')
        print(f'testY = {testY.shape}')
        # create and fit the convlstms network (convlstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        model.add(Conv1D(filters=256, kernel_size=2, activation=activation, input_shape=(look_back,1)))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(100, activation=activation))
        model.add(Dense(1))
    if  Model_Name.lower() == "lstm":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    if  Model_Name.lower() == "stacked lstm":
        print('Machine learning software = => create and fit the stacked lstm for Regression network...')
        # create and fit the Stacked LSTM for Regression network (stacked lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(NN, return_sequences=True, activation=activation, input_shape=(look_back, 1)))
        model.add(LSTM(20))
        model.add(Dense(1))     
    if  Model_Name.lower() == "gru":
        print('Machine learning software = => create and fit the lstm for Regression network...')
        # create and fit the LSTM for Regression network (lstm)
        N_epochs = int(input('Enter the number of epochs:'))
        inputloss_function =(input('Enter the Loss Function:'))
        inputoptimizer_name =(input('Enter the Optimizer Name:'))
        activation=(input('Enter the activation function name:'))
        NN=int(input('Enter the number of neurans:'))
        model.add(GRU(NN,activation=activation, input_shape=(look_back,1)))
        model.add(Dense(1))
    model.compile(loss=inputloss_function, optimizer=inputoptimizer_name,metrics=['accuracy'])
    history =model.fit(trainX, trainY, epochs=N_epochs, batch_size=1, verbose=True,validation_split=0.2, shuffle=True)
    print(history.history.keys())
    #  "Accuracy"
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('Accuracy.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    # "Loss" # plot train and validation loss
    fig = plt.figure(figsize=(12,4))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model train vs validation loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.grid()
    plt.show()
    fig.savefig('plot train and validation loss.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
    model.save(Model_Name)
else:
    model = load_model(Model_Name)
    model.summary()
# Out:
# Machine learning software = => create and fit the BILSTM for Regression network...
# Enter the number of epochs:300
# Enter the Loss Function:MeanSquaredError
# Enter the Optimizer Name:adam
# Enter the activation function name:relu
# Enter the number of neurans:200
# Epoch 1/300
# 636/636 [==============================] - 6s 7ms/step - loss: 0.0050 - accuracy: 0.1289 - val_loss: 8.1757e-04 - val_accuracy: 0.0126
# Epoch 2/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 8.7532e-04 - val_accuracy: 0.0126
# Epoch 3/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 4/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 5.5458e-04 - val_accuracy: 0.0126
# Epoch 5/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 4.4458e-04 - val_accuracy: 0.0126
# Epoch 6/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 4.7218e-04 - val_accuracy: 0.0126
# Epoch 7/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0013 - accuracy: 0.1289 - val_loss: 0.0042 - val_accuracy: 0.0126
# Epoch 8/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 4.4155e-04 - val_accuracy: 0.0126
# Epoch 9/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 8.8459e-04 - val_accuracy: 0.0126
# Epoch 10/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 3.9055e-04 - val_accuracy: 0.0126
# Epoch 11/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 3.9107e-04 - val_accuracy: 0.0126
# Epoch 12/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0049 - val_accuracy: 0.0126
# Epoch 13/300
# 636/636 [==============================] - 5s 7ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 4.4720e-04 - val_accuracy: 0.0126
# Epoch 14/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 15/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 16/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0061 - val_accuracy: 0.0126
# Epoch 17/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 18/300
# 636/636 [==============================] - 5s 7ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 19/300
# 636/636 [==============================] - 5s 8ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 20/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 21/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 9.3975e-04 - val_accuracy: 0.0126
# Epoch 22/300
# 636/636 [==============================] - 5s 8ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0048 - val_accuracy: 0.0126
# Epoch 23/300
# 636/636 [==============================] - 5s 8ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 24/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0012 - accuracy: 0.1289 - val_loss: 8.4298e-04 - val_accuracy: 0.0126
# Epoch 25/300
# 636/636 [==============================] - 5s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.6038e-04 - val_accuracy: 0.0126
# Epoch 26/300
# 636/636 [==============================] - 5s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.8683e-04 - val_accuracy: 0.0126
# Epoch 27/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.0762e-04 - val_accuracy: 0.0126
# Epoch 28/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.3975e-04 - val_accuracy: 0.0126
# Epoch 29/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 8.2800e-04 - val_accuracy: 0.0126
# Epoch 30/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.1291e-04 - val_accuracy: 0.0126
# Epoch 31/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 32/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 6.2391e-04 - val_accuracy: 0.0126
# Epoch 33/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 34/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0038 - val_accuracy: 0.0126
# Epoch 35/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 4.2277e-04 - val_accuracy: 0.0126
# Epoch 36/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.5436e-04 - val_accuracy: 0.0126
# Epoch 37/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 38/300
# 636/636 [==============================] - 5s 8ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.8633e-04 - val_accuracy: 0.0126
# Epoch 39/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0011 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 40/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 6.6548e-04 - val_accuracy: 0.0126
# Epoch 41/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.7577e-04 - val_accuracy: 0.0126
# Epoch 42/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.9188e-04 - val_accuracy: 0.0126
# Epoch 43/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.8629e-04 - accuracy: 0.1289 - val_loss: 9.3798e-04 - val_accuracy: 0.0126
# Epoch 44/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 45/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.5175e-04 - val_accuracy: 0.0126
# Epoch 46/300
# 636/636 [==============================] - 5s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 47/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 48/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 3.6899e-04 - val_accuracy: 0.0126
# Epoch 49/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.9136e-04 - accuracy: 0.1289 - val_loss: 0.0025 - val_accuracy: 0.0126
# Epoch 50/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 8.8422e-04 - val_accuracy: 0.0126
# Epoch 51/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.9013e-04 - accuracy: 0.1289 - val_loss: 4.1514e-04 - val_accuracy: 0.0126
# Epoch 52/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 9.3614e-04 - val_accuracy: 0.0126
# Epoch 53/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 5.8804e-04 - val_accuracy: 0.0126
# Epoch 54/300
# 636/636 [==============================] - 4s 7ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 4.0944e-04 - val_accuracy: 0.0126
# Epoch 55/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.9107e-04 - accuracy: 0.1289 - val_loss: 4.4439e-04 - val_accuracy: 0.0126
# Epoch 56/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.9446e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 57/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.8064e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 58/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.8570e-04 - accuracy: 0.1289 - val_loss: 5.5331e-04 - val_accuracy: 0.0126
# Epoch 59/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.9634e-04 - accuracy: 0.1289 - val_loss: 6.5203e-04 - val_accuracy: 0.0126
# Epoch 60/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5116e-04 - accuracy: 0.1289 - val_loss: 7.1266e-04 - val_accuracy: 0.0126
# Epoch 61/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 62/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.8415e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 63/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.8308e-04 - accuracy: 0.1289 - val_loss: 4.8325e-04 - val_accuracy: 0.0126
# Epoch 64/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.9044e-04 - accuracy: 0.1289 - val_loss: 4.5617e-04 - val_accuracy: 0.0126
# Epoch 65/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.6871e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 66/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5281e-04 - accuracy: 0.1289 - val_loss: 4.8017e-04 - val_accuracy: 0.0126
# Epoch 67/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.9829e-04 - accuracy: 0.1289 - val_loss: 5.0106e-04 - val_accuracy: 0.0126
# Epoch 68/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.9949e-04 - accuracy: 0.1289 - val_loss: 8.0436e-04 - val_accuracy: 0.0126
# Epoch 69/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.8589e-04 - accuracy: 0.1289 - val_loss: 0.0054 - val_accuracy: 0.0126
# Epoch 70/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.9804e-04 - accuracy: 0.1289 - val_loss: 4.9205e-04 - val_accuracy: 0.0126
# Epoch 71/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.8440e-04 - accuracy: 0.1289 - val_loss: 4.6697e-04 - val_accuracy: 0.0126
# Epoch 72/300
# 636/636 [==============================] - 4s 6ms/step - loss: 0.0010 - accuracy: 0.1289 - val_loss: 0.0020 - val_accuracy: 0.0126
# Epoch 73/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.8424e-04 - accuracy: 0.1289 - val_loss: 4.9354e-04 - val_accuracy: 0.0126
# Epoch 74/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.5904e-04 - accuracy: 0.1289 - val_loss: 6.5965e-04 - val_accuracy: 0.0126
# Epoch 75/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.9836e-04 - accuracy: 0.1289 - val_loss: 8.4448e-04 - val_accuracy: 0.0126
# Epoch 76/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.6201e-04 - accuracy: 0.1289 - val_loss: 4.5525e-04 - val_accuracy: 0.0126
# Epoch 77/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.4746e-04 - accuracy: 0.1289 - val_loss: 4.2375e-04 - val_accuracy: 0.0126
# Epoch 78/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.8181e-04 - accuracy: 0.1289 - val_loss: 0.0028 - val_accuracy: 0.0126
# Epoch 79/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.4433e-04 - accuracy: 0.1289 - val_loss: 8.2003e-04 - val_accuracy: 0.0126
# Epoch 80/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.7522e-04 - accuracy: 0.1289 - val_loss: 4.6426e-04 - val_accuracy: 0.0126
# Epoch 81/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.7282e-04 - accuracy: 0.1289 - val_loss: 7.1663e-04 - val_accuracy: 0.0126
# Epoch 82/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.7597e-04 - accuracy: 0.1289 - val_loss: 4.0940e-04 - val_accuracy: 0.0126
# Epoch 83/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.7682e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 84/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5498e-04 - accuracy: 0.1289 - val_loss: 3.9482e-04 - val_accuracy: 0.0126
# Epoch 85/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5526e-04 - accuracy: 0.1289 - val_loss: 8.0247e-04 - val_accuracy: 0.0126
# Epoch 86/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2824e-04 - accuracy: 0.1289 - val_loss: 5.9606e-04 - val_accuracy: 0.0126
# Epoch 87/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.4907e-04 - accuracy: 0.1289 - val_loss: 0.0070 - val_accuracy: 0.0126
# Epoch 88/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5136e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 89/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4027e-04 - accuracy: 0.1289 - val_loss: 0.0033 - val_accuracy: 0.0126
# Epoch 90/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5204e-04 - accuracy: 0.1289 - val_loss: 0.0049 - val_accuracy: 0.0126
# Epoch 91/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.7102e-04 - accuracy: 0.1289 - val_loss: 0.0017 - val_accuracy: 0.0126
# Epoch 92/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4308e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 93/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.9047e-04 - accuracy: 0.1289 - val_loss: 5.1377e-04 - val_accuracy: 0.0126
# Epoch 94/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5627e-04 - accuracy: 0.1289 - val_loss: 0.0034 - val_accuracy: 0.0126
# Epoch 95/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.7333e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 96/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3778e-04 - accuracy: 0.1289 - val_loss: 5.9524e-04 - val_accuracy: 0.0126
# Epoch 97/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5386e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 98/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.6616e-04 - accuracy: 0.1289 - val_loss: 4.5335e-04 - val_accuracy: 0.0126
# Epoch 99/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4222e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 100/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4799e-04 - accuracy: 0.1289 - val_loss: 4.5769e-04 - val_accuracy: 0.0126
# Epoch 101/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3410e-04 - accuracy: 0.1289 - val_loss: 0.0063 - val_accuracy: 0.0126
# Epoch 102/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5769e-04 - accuracy: 0.1289 - val_loss: 5.7369e-04 - val_accuracy: 0.0126
# Epoch 103/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.7577e-04 - accuracy: 0.1289 - val_loss: 5.9166e-04 - val_accuracy: 0.0126
# Epoch 104/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3055e-04 - accuracy: 0.1289 - val_loss: 7.2796e-04 - val_accuracy: 0.0126
# Epoch 105/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.3524e-04 - accuracy: 0.1289 - val_loss: 5.6787e-04 - val_accuracy: 0.0126
# Epoch 106/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.4664e-04 - accuracy: 0.1289 - val_loss: 0.0036 - val_accuracy: 0.0126
# Epoch 107/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3828e-04 - accuracy: 0.1289 - val_loss: 0.0049 - val_accuracy: 0.0126
# Epoch 108/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.5647e-04 - accuracy: 0.1289 - val_loss: 5.6701e-04 - val_accuracy: 0.0126
# Epoch 109/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1359e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 110/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4430e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 111/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5884e-04 - accuracy: 0.1289 - val_loss: 9.1206e-04 - val_accuracy: 0.0126
# Epoch 112/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5068e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 113/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2376e-04 - accuracy: 0.1289 - val_loss: 8.8351e-04 - val_accuracy: 0.0126
# Epoch 114/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1320e-04 - accuracy: 0.1289 - val_loss: 6.2931e-04 - val_accuracy: 0.0126
# Epoch 115/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5130e-04 - accuracy: 0.1289 - val_loss: 4.8954e-04 - val_accuracy: 0.0126
# Epoch 116/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5329e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 117/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0425e-04 - accuracy: 0.1289 - val_loss: 4.7065e-04 - val_accuracy: 0.0126
# Epoch 118/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.6274e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 119/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1782e-04 - accuracy: 0.1289 - val_loss: 5.5195e-04 - val_accuracy: 0.0126
# Epoch 120/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2512e-04 - accuracy: 0.1289 - val_loss: 5.3167e-04 - val_accuracy: 0.0126
# Epoch 121/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1379e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 122/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2236e-04 - accuracy: 0.1289 - val_loss: 6.7832e-04 - val_accuracy: 0.0126
# Epoch 123/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.4088e-04 - accuracy: 0.1289 - val_loss: 4.9826e-04 - val_accuracy: 0.0126
# Epoch 124/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3502e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 125/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.3973e-04 - accuracy: 0.1289 - val_loss: 5.1210e-04 - val_accuracy: 0.0126
# Epoch 126/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4953e-04 - accuracy: 0.1289 - val_loss: 5.9737e-04 - val_accuracy: 0.0126
# Epoch 127/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.3336e-04 - accuracy: 0.1289 - val_loss: 4.4559e-04 - val_accuracy: 0.0126
# Epoch 128/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3674e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 129/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.7556e-04 - accuracy: 0.1289 - val_loss: 4.9328e-04 - val_accuracy: 0.0126
# Epoch 130/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.1221e-04 - accuracy: 0.1289 - val_loss: 5.0045e-04 - val_accuracy: 0.0126
# Epoch 131/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.4588e-04 - accuracy: 0.1289 - val_loss: 7.3989e-04 - val_accuracy: 0.0126
# Epoch 132/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1367e-04 - accuracy: 0.1289 - val_loss: 4.8531e-04 - val_accuracy: 0.0126
# Epoch 133/300
# 636/636 [==============================] - 4s 7ms/step - loss: 8.9391e-04 - accuracy: 0.1289 - val_loss: 5.9009e-04 - val_accuracy: 0.0126
# Epoch 134/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.5144e-04 - accuracy: 0.1289 - val_loss: 4.7777e-04 - val_accuracy: 0.0126
# Epoch 135/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.5397e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 136/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.2413e-04 - accuracy: 0.1289 - val_loss: 7.6228e-04 - val_accuracy: 0.0126
# Epoch 137/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2057e-04 - accuracy: 0.1289 - val_loss: 4.6877e-04 - val_accuracy: 0.0126
# Epoch 138/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3699e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 139/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.2507e-04 - accuracy: 0.1289 - val_loss: 5.9695e-04 - val_accuracy: 0.0126
# Epoch 140/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.0848e-04 - accuracy: 0.1289 - val_loss: 4.9380e-04 - val_accuracy: 0.0126
# Epoch 141/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2953e-04 - accuracy: 0.1289 - val_loss: 4.7744e-04 - val_accuracy: 0.0126
# Epoch 142/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.1637e-04 - accuracy: 0.1289 - val_loss: 4.1493e-04 - val_accuracy: 0.0126
# Epoch 143/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.0745e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 144/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0327e-04 - accuracy: 0.1289 - val_loss: 8.8813e-04 - val_accuracy: 0.0126
# Epoch 145/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.0750e-04 - accuracy: 0.1289 - val_loss: 8.2283e-04 - val_accuracy: 0.0126
# Epoch 146/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.0085e-04 - accuracy: 0.1289 - val_loss: 5.2988e-04 - val_accuracy: 0.0126
# Epoch 147/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.1903e-04 - accuracy: 0.1289 - val_loss: 5.8207e-04 - val_accuracy: 0.0126
# Epoch 148/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.2969e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 149/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2083e-04 - accuracy: 0.1289 - val_loss: 9.6538e-04 - val_accuracy: 0.0126
# Epoch 150/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0618e-04 - accuracy: 0.1289 - val_loss: 3.8925e-04 - val_accuracy: 0.0126
# Epoch 151/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0763e-04 - accuracy: 0.1289 - val_loss: 6.4501e-04 - val_accuracy: 0.0126
# Epoch 152/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2940e-04 - accuracy: 0.1289 - val_loss: 5.5088e-04 - val_accuracy: 0.0126
# Epoch 153/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.8060e-04 - accuracy: 0.1289 - val_loss: 7.2556e-04 - val_accuracy: 0.0126
# Epoch 154/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.3377e-04 - accuracy: 0.1289 - val_loss: 4.0558e-04 - val_accuracy: 0.0126
# Epoch 155/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.9485e-04 - accuracy: 0.1289 - val_loss: 6.1136e-04 - val_accuracy: 0.0126
# Epoch 156/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.9036e-04 - accuracy: 0.1289 - val_loss: 7.1938e-04 - val_accuracy: 0.0126
# Epoch 157/300
# 636/636 [==============================] - 4s 7ms/step - loss: 9.1819e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 158/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.4008e-04 - accuracy: 0.1289 - val_loss: 4.6812e-04 - val_accuracy: 0.0126
# Epoch 159/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0171e-04 - accuracy: 0.1289 - val_loss: 4.4513e-04 - val_accuracy: 0.0126
# Epoch 160/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1042e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 161/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0567e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 162/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.8071e-04 - accuracy: 0.1289 - val_loss: 4.6540e-04 - val_accuracy: 0.0126
# Epoch 163/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.9520e-04 - accuracy: 0.1289 - val_loss: 9.3408e-04 - val_accuracy: 0.0126
# Epoch 164/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.0322e-04 - accuracy: 0.1289 - val_loss: 6.1408e-04 - val_accuracy: 0.0126
# Epoch 165/300
# 636/636 [==============================] - 5s 7ms/step - loss: 8.9550e-04 - accuracy: 0.1289 - val_loss: 6.5128e-04 - val_accuracy: 0.0126
# Epoch 166/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0919e-04 - accuracy: 0.1289 - val_loss: 4.3694e-04 - val_accuracy: 0.0126
# Epoch 167/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0309e-04 - accuracy: 0.1289 - val_loss: 8.0013e-04 - val_accuracy: 0.0126
# Epoch 168/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0862e-04 - accuracy: 0.1289 - val_loss: 4.4135e-04 - val_accuracy: 0.0126
# Epoch 169/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.1881e-04 - accuracy: 0.1289 - val_loss: 4.8994e-04 - val_accuracy: 0.0126
# Epoch 170/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0907e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 171/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0881e-04 - accuracy: 0.1289 - val_loss: 0.0022 - val_accuracy: 0.0126
# Epoch 172/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.8622e-04 - accuracy: 0.1289 - val_loss: 0.0016 - val_accuracy: 0.0126
# Epoch 173/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.9160e-04 - accuracy: 0.1289 - val_loss: 4.8460e-04 - val_accuracy: 0.0126
# Epoch 174/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.0496e-04 - accuracy: 0.1289 - val_loss: 4.4887e-04 - val_accuracy: 0.0126
# Epoch 175/300
# 636/636 [==============================] - 4s 6ms/step - loss: 9.2509e-04 - accuracy: 0.1289 - val_loss: 5.8211e-04 - val_accuracy: 0.0126
# Epoch 176/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.9542e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 177/300
# 636/636 [==============================] - 5s 7ms/step - loss: 9.1619e-04 - accuracy: 0.1289 - val_loss: 3.6878e-04 - val_accuracy: 0.0126
# Epoch 178/300
# 636/636 [==============================] - 5s 8ms/step - loss: 9.0140e-04 - accuracy: 0.1289 - val_loss: 9.9225e-04 - val_accuracy: 0.0126
# Epoch 179/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0614e-04 - accuracy: 0.1289 - val_loss: 3.8745e-04 - val_accuracy: 0.0126
# Epoch 180/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.0360e-04 - accuracy: 0.1289 - val_loss: 5.9161e-04 - val_accuracy: 0.0126
# Epoch 181/300
# 636/636 [==============================] - 7s 10ms/step - loss: 9.1383e-04 - accuracy: 0.1289 - val_loss: 4.6706e-04 - val_accuracy: 0.0126
# Epoch 182/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.9418e-04 - accuracy: 0.1289 - val_loss: 4.3184e-04 - val_accuracy: 0.0126
# Epoch 183/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8578e-04 - accuracy: 0.1289 - val_loss: 0.0015 - val_accuracy: 0.0126
# Epoch 184/300
# 636/636 [==============================] - 8s 12ms/step - loss: 9.1089e-04 - accuracy: 0.1289 - val_loss: 4.1935e-04 - val_accuracy: 0.0126
# Epoch 185/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8278e-04 - accuracy: 0.1289 - val_loss: 4.5499e-04 - val_accuracy: 0.0126
# Epoch 186/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.8308e-04 - accuracy: 0.1289 - val_loss: 4.1795e-04 - val_accuracy: 0.0126
# Epoch 187/300
# 636/636 [==============================] - 8s 12ms/step - loss: 9.1341e-04 - accuracy: 0.1289 - val_loss: 5.7980e-04 - val_accuracy: 0.0126
# Epoch 188/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1112e-04 - accuracy: 0.1289 - val_loss: 3.9933e-04 - val_accuracy: 0.0126
# Epoch 189/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9446e-04 - accuracy: 0.1289 - val_loss: 4.3801e-04 - val_accuracy: 0.0126
# Epoch 190/300
# 636/636 [==============================] - 7s 12ms/step - loss: 9.0908e-04 - accuracy: 0.1289 - val_loss: 7.3367e-04 - val_accuracy: 0.0126
# Epoch 191/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9297e-04 - accuracy: 0.1289 - val_loss: 5.4129e-04 - val_accuracy: 0.0126
# Epoch 192/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9440e-04 - accuracy: 0.1289 - val_loss: 4.4547e-04 - val_accuracy: 0.0126
# Epoch 193/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8138e-04 - accuracy: 0.1289 - val_loss: 4.5909e-04 - val_accuracy: 0.0126
# Epoch 194/300
# 636/636 [==============================] - 7s 12ms/step - loss: 9.0309e-04 - accuracy: 0.1289 - val_loss: 4.0680e-04 - val_accuracy: 0.0126
# Epoch 195/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.9984e-04 - accuracy: 0.1289 - val_loss: 3.9322e-04 - val_accuracy: 0.0126
# Epoch 196/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8188e-04 - accuracy: 0.1289 - val_loss: 4.3570e-04 - val_accuracy: 0.0126
# Epoch 197/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1791e-04 - accuracy: 0.1289 - val_loss: 3.6809e-04 - val_accuracy: 0.0126
# Epoch 198/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.9032e-04 - accuracy: 0.1289 - val_loss: 7.3335e-04 - val_accuracy: 0.0126
# Epoch 199/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1206e-04 - accuracy: 0.1289 - val_loss: 6.1362e-04 - val_accuracy: 0.0126
# Epoch 200/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0738e-04 - accuracy: 0.1289 - val_loss: 4.9088e-04 - val_accuracy: 0.0126
# Epoch 201/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0203e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 202/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8912e-04 - accuracy: 0.1289 - val_loss: 4.7635e-04 - val_accuracy: 0.0126
# Epoch 203/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8663e-04 - accuracy: 0.1289 - val_loss: 4.7244e-04 - val_accuracy: 0.0126
# Epoch 204/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8711e-04 - accuracy: 0.1289 - val_loss: 4.9961e-04 - val_accuracy: 0.0126
# Epoch 205/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7025e-04 - accuracy: 0.1289 - val_loss: 7.9576e-04 - val_accuracy: 0.0126
# Epoch 206/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9062e-04 - accuracy: 0.1289 - val_loss: 5.6209e-04 - val_accuracy: 0.0126
# Epoch 207/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8331e-04 - accuracy: 0.1289 - val_loss: 4.0498e-04 - val_accuracy: 0.0126
# Epoch 208/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.2376e-04 - accuracy: 0.1289 - val_loss: 9.6015e-04 - val_accuracy: 0.0126
# Epoch 209/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.1127e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 210/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.8662e-04 - accuracy: 0.1289 - val_loss: 6.3799e-04 - val_accuracy: 0.0126
# Epoch 211/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0453e-04 - accuracy: 0.1289 - val_loss: 3.6751e-04 - val_accuracy: 0.0126
# Epoch 212/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8927e-04 - accuracy: 0.1289 - val_loss: 7.2211e-04 - val_accuracy: 0.0126
# Epoch 213/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.2874e-04 - accuracy: 0.1289 - val_loss: 5.0850e-04 - val_accuracy: 0.0126
# Epoch 214/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.9045e-04 - accuracy: 0.1289 - val_loss: 4.0518e-04 - val_accuracy: 0.0126
# Epoch 215/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.9341e-04 - accuracy: 0.1289 - val_loss: 4.0317e-04 - val_accuracy: 0.0126
# Epoch 216/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8617e-04 - accuracy: 0.1289 - val_loss: 7.3120e-04 - val_accuracy: 0.0126
# Epoch 217/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8485e-04 - accuracy: 0.1289 - val_loss: 5.8727e-04 - val_accuracy: 0.0126
# Epoch 218/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.2452e-04 - accuracy: 0.1289 - val_loss: 0.0014 - val_accuracy: 0.0126
# Epoch 219/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.7145e-04 - accuracy: 0.1289 - val_loss: 5.0593e-04 - val_accuracy: 0.0126
# Epoch 220/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8656e-04 - accuracy: 0.1289 - val_loss: 4.0992e-04 - val_accuracy: 0.0126
# Epoch 221/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.6920e-04 - accuracy: 0.1289 - val_loss: 5.1800e-04 - val_accuracy: 0.0126
# Epoch 222/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8257e-04 - accuracy: 0.1289 - val_loss: 5.7677e-04 - val_accuracy: 0.0126
# Epoch 223/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8580e-04 - accuracy: 0.1289 - val_loss: 4.5906e-04 - val_accuracy: 0.0126
# Epoch 224/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7014e-04 - accuracy: 0.1289 - val_loss: 4.2576e-04 - val_accuracy: 0.0126
# Epoch 225/300
# 636/636 [==============================] - 6s 10ms/step - loss: 9.1756e-04 - accuracy: 0.1289 - val_loss: 4.3492e-04 - val_accuracy: 0.0126
# Epoch 226/300
# 636/636 [==============================] - 8s 13ms/step - loss: 8.8072e-04 - accuracy: 0.1289 - val_loss: 7.3566e-04 - val_accuracy: 0.0126
# Epoch 227/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.9310e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 228/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9509e-04 - accuracy: 0.1289 - val_loss: 4.2960e-04 - val_accuracy: 0.0126
# Epoch 229/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.8008e-04 - accuracy: 0.1289 - val_loss: 7.5220e-04 - val_accuracy: 0.0126
# Epoch 230/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.8199e-04 - accuracy: 0.1289 - val_loss: 4.4711e-04 - val_accuracy: 0.0126
# Epoch 231/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.9506e-04 - accuracy: 0.1289 - val_loss: 8.2874e-04 - val_accuracy: 0.0126
# Epoch 232/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9050e-04 - accuracy: 0.1289 - val_loss: 7.6975e-04 - val_accuracy: 0.0126
# Epoch 233/300
# 636/636 [==============================] - 8s 13ms/step - loss: 8.6446e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 234/300
# 636/636 [==============================] - 8s 12ms/step - loss: 9.0949e-04 - accuracy: 0.1289 - val_loss: 5.9705e-04 - val_accuracy: 0.0126
# Epoch 235/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9624e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 236/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.7162e-04 - accuracy: 0.1289 - val_loss: 4.2851e-04 - val_accuracy: 0.0126
# Epoch 237/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7745e-04 - accuracy: 0.1289 - val_loss: 3.9446e-04 - val_accuracy: 0.0126
# Epoch 238/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7235e-04 - accuracy: 0.1289 - val_loss: 4.6411e-04 - val_accuracy: 0.0126
# Epoch 239/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0460e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 240/300
# 636/636 [==============================] - 6s 9ms/step - loss: 8.8851e-04 - accuracy: 0.1289 - val_loss: 4.5515e-04 - val_accuracy: 0.0126
# Epoch 241/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.8062e-04 - accuracy: 0.1289 - val_loss: 4.1174e-04 - val_accuracy: 0.0126
# Epoch 242/300
# 636/636 [==============================] - 4s 7ms/step - loss: 8.7932e-04 - accuracy: 0.1289 - val_loss: 4.0996e-04 - val_accuracy: 0.0126
# Epoch 243/300
# 636/636 [==============================] - 4s 6ms/step - loss: 8.8590e-04 - accuracy: 0.1289 - val_loss: 6.8204e-04 - val_accuracy: 0.0126
# Epoch 244/300
# 636/636 [==============================] - 4s 7ms/step - loss: 8.8768e-04 - accuracy: 0.1289 - val_loss: 9.2925e-04 - val_accuracy: 0.0126
# Epoch 245/300
# 636/636 [==============================] - 4s 7ms/step - loss: 8.9426e-04 - accuracy: 0.1289 - val_loss: 7.6154e-04 - val_accuracy: 0.0126
# Epoch 246/300
# 636/636 [==============================] - 5s 8ms/step - loss: 8.5505e-04 - accuracy: 0.1289 - val_loss: 4.0978e-04 - val_accuracy: 0.0126
# Epoch 247/300
# 636/636 [==============================] - 6s 9ms/step - loss: 8.7420e-04 - accuracy: 0.1289 - val_loss: 4.0685e-04 - val_accuracy: 0.0126
# Epoch 248/300
# 636/636 [==============================] - 6s 9ms/step - loss: 8.7494e-04 - accuracy: 0.1289 - val_loss: 0.0019 - val_accuracy: 0.0126
# Epoch 249/300
# 636/636 [==============================] - 6s 9ms/step - loss: 8.8410e-04 - accuracy: 0.1289 - val_loss: 0.0012 - val_accuracy: 0.0126
# Epoch 250/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0298e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 251/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.9461e-04 - accuracy: 0.1289 - val_loss: 5.3642e-04 - val_accuracy: 0.0126
# Epoch 252/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0240e-04 - accuracy: 0.1289 - val_loss: 4.3251e-04 - val_accuracy: 0.0126
# Epoch 253/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8428e-04 - accuracy: 0.1289 - val_loss: 0.0013 - val_accuracy: 0.0126
# Epoch 254/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6944e-04 - accuracy: 0.1289 - val_loss: 4.0113e-04 - val_accuracy: 0.0126
# Epoch 255/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.5663e-04 - accuracy: 0.1289 - val_loss: 3.8198e-04 - val_accuracy: 0.0126
# Epoch 256/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.6081e-04 - accuracy: 0.1289 - val_loss: 4.6196e-04 - val_accuracy: 0.0126
# Epoch 257/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.8978e-04 - accuracy: 0.1289 - val_loss: 3.7568e-04 - val_accuracy: 0.0126
# Epoch 258/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7136e-04 - accuracy: 0.1289 - val_loss: 3.9426e-04 - val_accuracy: 0.0126
# Epoch 259/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7502e-04 - accuracy: 0.1289 - val_loss: 5.4006e-04 - val_accuracy: 0.0126
# Epoch 260/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0498e-04 - accuracy: 0.1289 - val_loss: 4.4220e-04 - val_accuracy: 0.0126
# Epoch 261/300
# 636/636 [==============================] - 8s 13ms/step - loss: 9.0522e-04 - accuracy: 0.1289 - val_loss: 5.8263e-04 - val_accuracy: 0.0126
# Epoch 262/300
# 636/636 [==============================] - 8s 13ms/step - loss: 8.7756e-04 - accuracy: 0.1289 - val_loss: 4.0249e-04 - val_accuracy: 0.0126
# Epoch 263/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.6811e-04 - accuracy: 0.1289 - val_loss: 3.9755e-04 - val_accuracy: 0.0126
# Epoch 264/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8834e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 265/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0580e-04 - accuracy: 0.1289 - val_loss: 3.9049e-04 - val_accuracy: 0.0126
# Epoch 266/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6619e-04 - accuracy: 0.1289 - val_loss: 0.0018 - val_accuracy: 0.0126
# Epoch 267/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7394e-04 - accuracy: 0.1289 - val_loss: 0.0010 - val_accuracy: 0.0126
# Epoch 268/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8432e-04 - accuracy: 0.1289 - val_loss: 8.6747e-04 - val_accuracy: 0.0126
# Epoch 269/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9832e-04 - accuracy: 0.1289 - val_loss: 4.2032e-04 - val_accuracy: 0.0126
# Epoch 270/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9674e-04 - accuracy: 0.1289 - val_loss: 3.7910e-04 - val_accuracy: 0.0126
# Epoch 271/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8788e-04 - accuracy: 0.1289 - val_loss: 6.7966e-04 - val_accuracy: 0.0126
# Epoch 272/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0466e-04 - accuracy: 0.1289 - val_loss: 3.9622e-04 - val_accuracy: 0.0126
# Epoch 273/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7903e-04 - accuracy: 0.1289 - val_loss: 3.7593e-04 - val_accuracy: 0.0126
# Epoch 274/300
# 636/636 [==============================] - 6s 10ms/step - loss: 8.6775e-04 - accuracy: 0.1289 - val_loss: 4.6854e-04 - val_accuracy: 0.0126
# Epoch 275/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.6051e-04 - accuracy: 0.1289 - val_loss: 3.9914e-04 - val_accuracy: 0.0126
# Epoch 276/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7154e-04 - accuracy: 0.1289 - val_loss: 3.7263e-04 - val_accuracy: 0.0126
# Epoch 277/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5119e-04 - accuracy: 0.1289 - val_loss: 3.8830e-04 - val_accuracy: 0.0126
# Epoch 278/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.7592e-04 - accuracy: 0.1289 - val_loss: 4.6382e-04 - val_accuracy: 0.0126
# Epoch 279/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7307e-04 - accuracy: 0.1289 - val_loss: 4.3523e-04 - val_accuracy: 0.0126
# Epoch 280/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7599e-04 - accuracy: 0.1289 - val_loss: 5.2047e-04 - val_accuracy: 0.0126
# Epoch 281/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.5527e-04 - accuracy: 0.1289 - val_loss: 3.8562e-04 - val_accuracy: 0.0126
# Epoch 282/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.7059e-04 - accuracy: 0.1289 - val_loss: 4.6786e-04 - val_accuracy: 0.0126
# Epoch 283/300
# 636/636 [==============================] - 7s 12ms/step - loss: 8.9018e-04 - accuracy: 0.1289 - val_loss: 4.7070e-04 - val_accuracy: 0.0126
# Epoch 284/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.5910e-04 - accuracy: 0.1289 - val_loss: 4.0536e-04 - val_accuracy: 0.0126
# Epoch 285/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.8690e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 286/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5822e-04 - accuracy: 0.1289 - val_loss: 0.0021 - val_accuracy: 0.0126
# Epoch 287/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.9008e-04 - accuracy: 0.1289 - val_loss: 8.7948e-04 - val_accuracy: 0.0126
# Epoch 288/300
# 636/636 [==============================] - 7s 11ms/step - loss: 9.0188e-04 - accuracy: 0.1289 - val_loss: 4.3440e-04 - val_accuracy: 0.0126
# Epoch 289/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7605e-04 - accuracy: 0.1289 - val_loss: 5.3614e-04 - val_accuracy: 0.0126
# Epoch 290/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.7513e-04 - accuracy: 0.1289 - val_loss: 8.2922e-04 - val_accuracy: 0.0126
# Epoch 291/300
# 636/636 [==============================] - 7s 10ms/step - loss: 8.5611e-04 - accuracy: 0.1289 - val_loss: 4.9157e-04 - val_accuracy: 0.0126
# Epoch 292/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8366e-04 - accuracy: 0.1289 - val_loss: 4.1251e-04 - val_accuracy: 0.0126
# Epoch 293/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6248e-04 - accuracy: 0.1289 - val_loss: 0.0011 - val_accuracy: 0.0126
# Epoch 294/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.5422e-04 - accuracy: 0.1289 - val_loss: 4.4604e-04 - val_accuracy: 0.0126
# Epoch 295/300
# 636/636 [==============================] - 8s 13ms/step - loss: 8.6642e-04 - accuracy: 0.1289 - val_loss: 3.6363e-04 - val_accuracy: 0.0126
# Epoch 296/300
# 636/636 [==============================] - 8s 12ms/step - loss: 8.6083e-04 - accuracy: 0.1289 - val_loss: 5.7129e-04 - val_accuracy: 0.0126
# Epoch 297/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7249e-04 - accuracy: 0.1289 - val_loss: 3.6917e-04 - val_accuracy: 0.0126
# Epoch 298/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.6653e-04 - accuracy: 0.1289 - val_loss: 3.6966e-04 - val_accuracy: 0.0126
# Epoch 299/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.7115e-04 - accuracy: 0.1289 - val_loss: 4.3008e-04 - val_accuracy: 0.0126
# Epoch 300/300
# 636/636 [==============================] - 7s 11ms/step - loss: 8.8936e-04 - accuracy: 0.1289 - val_loss: 4.9935e-04 - val_accuracy: 0.0126
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# INFO:tensorflow:Assets written to: bilstm/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa382414dd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fa385257710> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
losses_lstm = model.history.history['loss']
fig = plt.figure(figsize=(12,4))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(range(len(losses_lstm)),losses_lstm)
plt.grid()
fig.savefig('losses lstm.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')
model.summary()
model.save('LSTM.h5')
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (None, 400)              323200
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 401
#
# =================================================================
# Total params: 323,601
# Trainable params: 323,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions
print(f'trainPredict {trainPredict.shape}')
print(f'trainY {trainY.shape}')
print(f'testPredict {testPredict.shape}')
print(f'testY {testY.shape}')
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# Out:
# trainPredict (795, 1)
# trainY (795,)
# testPredict (39, 1)
# testY (39,)

# %%
#Mean Squared Error
trainScore_MSE = mean_squared_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore_MSE))
testScore_MSE = mean_squared_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MSE' % (testScore_MSE))
# calculate root mean squared error
trainScore_RMSE = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore_RMSE))
testScore_RMSE = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore_RMSE))
#  Mean Absolute Error
trainScore_MAE = mean_absolute_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAE' % (trainScore_MAE))
testScore_MAE = mean_absolute_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAE' % (testScore_MAE))
#  Mean Absolute Percentage Error
trainScore_MAPE = mean_absolute_percentage_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAPE' % (trainScore_MAPE))
testScore_MAPE = mean_absolute_percentage_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAPE' % (testScore_MAPE))

#  Coefficient of Determination-R2 score
trainScore_r2 = r2_score(trainY[0], trainPredict[:,0])
print('Train Score: %.2f r2' % (trainScore_r2))
testScore_r2= r2_score(testY[0], testPredict[:,0])
print('Test Score: %.2f r2' % (testScore_r2))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# Out:
# Train Score: 1229.32 MSE
# Test Score: 1406.02 MSE
# Train Score: 35.06 RMSE
# Test Score: 37.50 RMSE
# Train Score: 25.22 MAE
# Test Score: 32.73 MAE
# Train Score: 2752504594304720.00 MAPE
# Test Score: 0.10 MAPE
# Train Score: 0.99 r2
# Test Score: 0.88 r2

# %%
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
fig = plt.figure(figsize=(12,4))
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title(plot_title) 
plt.legend([Implementation, 'training','testing'], loc='upper left')
plt.xlabel(f'Time in {Time}')
plt.ylabel(Implementation)
plt.grid()
plt.show()
fig.savefig('final.png', dpi=fig.dpi, facecolor='white', bbox_inches='tight')

# %%
# predictions = model.predict() #this creates states
future_x = []
future_y = []
currentStep = dataset[-look_back:] #last step from the previous prediction
# model.reset_states()
for i in range(Forecasting_days):
    predicted = model.predict(currentStep.reshape(1,look_back,1)) #get the next step
    future_x.append(currentStep) #store the future steps \
    future_y.append(predicted)
    future_y[i] = np.reshape(scaler.inverse_transform(future_y[i]), 1)
    currentStep = np.concatenate((currentStep[1:], predicted), axis=0).astype(np.float32)
future_predictions_x = pd.DataFrame(np.array(future_x).reshape(Forecasting_days,look_back))
future_predictions_y = pd.DataFrame(future_y,columns=['Future'])
# print(future_predictions_x)
print(future_predictions_y)
# Out:
#        Future
# 0  214.662170
# 1  226.356110
# 2  249.913116
# 3  263.756409
# 4  280.756378
# 5  293.292969
# 6  306.685425
# 7  318.775818
# 8  333.146820
# 9  346.143707

# %%
file1 = open('Accuracy.txt', 'w')
file1.write(f'Train Score r2 %.2f : {trainScore_r2}\n Test Score r2 %.2f r2: {testScore_r2}\n Train Score MSE: {trainScore_MSE}\n Test Score MSE: {testScore_MSE}\n Train Score RMSE: {trainScore_RMSE}\n test Score RMSE: {testScore_RMSE}\n Train Score MAE: {trainScore_MAE}\n Test Score MAE: {testScore_MAE}\n Train Score MAPE: {trainScore_MAPE}\n Test Score MAPE: {testScore_MAPE}')
file1.close()

# %%
file2 = open('Prediction.txt', 'w')
file2.write(f'Prediction:\n {future_predictions_y}')
file2.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
